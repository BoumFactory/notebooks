# %% [markdown]
# # 🐢 Dessiner avec la Tortue Python
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Seconde<br>
#     <strong>🎯 Thème :</strong> Programmation graphique et géométrie<br>
#     <strong>⏱️ Durée estimée :</strong> 60 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# À la fin de cette activité, vous serez capable de :
# - ✅ Déplacer la tortue (avancer, reculer, tourner)
# - ✅ Contrôler le stylo (lever, poser, couleur, épaisseur)
# - ✅ Dessiner des formes géométriques (carrés, triangles, polygones)
# - ✅ Utiliser des boucles pour créer des motifs répétitifs
#
# ---
#
# ## 📋 Prérequis
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px;">
# Pour cette activité, vous devez savoir :
#
# - 📌 Utiliser des variables
# - 📌 Écrire des boucles `for` avec `range()`
# </div>
#
# ---
#
# ## 💡 Introduction
#
# Le module `turtle` (tortue en anglais) permet de dessiner en Python. Imaginez une tortue tenant un stylo : elle peut avancer, tourner, lever ou poser son stylo pour créer des dessins.
#
# <div style="background-color: #f0f4c3; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>🤔 Pourquoi turtle ?</strong> Ce module est parfait pour apprendre la programmation car :<br>
#     - On voit immédiatement le résultat de son code<br>
#     - Les concepts de géométrie prennent vie<br>
#     - On peut créer des dessins artistiques avec quelques lignes de code
# </div>
#
# <div style="background-color: #e8f5e9; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>📦 Dans ce notebook</strong>, nous utilisons <code>jupyturtle</code>, une version adaptée pour Jupyter.<br>
#     La syntaxe est très proche du module <code>turtle</code> standard de Python.
# </div>
#
# ---

# %% [markdown]
# ## ⚙️ Installation (à exécuter une seule fois)

# %%
# Exécutez cette cellule pour installer jupyturtle
# !pip install jupyturtle -q

# %% [markdown]
# ---
#
# ## 📚 Référence des commandes
#
# <div style="background-color: #e8f5e9; padding: 15px; border-radius: 10px;">
#
# ### Commandes de déplacement
#
# | Commande | Description |
# |----------|-------------|
# | `forward(d)` / `fd(d)` | Avance de d pixels |
# | `back(d)` / `bk(d)` | Recule de d pixels |
# | `left(a)` / `lt(a)` | Tourne à gauche de a degrés |
# | `right(a)` / `rt(a)` | Tourne à droite de a degrés |
#
# ### Commandes du stylo
#
# | Commande | Description |
# |----------|-------------|
# | `pen_up()` | Lève le stylo (ne trace plus) |
# | `pen_down()` | Pose le stylo (trace) |
# | `set_color(c)` | Définit la couleur du trait |
# | `set_width(e)` | Définit l'épaisseur du trait |
#
# ### Commande essentielle
#
# | Commande | Description |
# |----------|-------------|
# | `make_turtle()` | Crée un nouveau dessin |
#
# ### Formule polygone régulier
#
# **Angle de rotation = 360° / nombre de côtés**
#
# </div>
#
# <div style="background-color: #ffebee; padding: 10px; border-radius: 5px; margin-top: 10px;">
# ⚠️ <strong>Important :</strong> Chaque cellule doit commencer par <code>make_turtle()</code> pour créer un nouveau dessin.
# </div>
#
# ---

# %% [markdown]
# # 🎨 Partie 1 : Formes de base
#
# **Consigne :** Reproduisez chaque figure ci-dessous en écrivant le code correspondant.
#
# ---

# %% [markdown]
# ### Exercice 1 : Le carré
#
# Dessinez un **carré** de côté **80 pixels**.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=250, height=200)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=250, height=200)
#
# for i in range(4):
#     forward(80)
#     left(90)
# ```
#
# **Explication :** Un carré a 4 côtés égaux et des angles de 90°.
# </details>
#
# ---

# %% [markdown]
# ### Exercice 2 : Le rectangle
#
# Dessinez un **rectangle** de **120 pixels** de large et **60 pixels** de haut.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=320, height=180)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=320, height=180)
#
# for i in range(2):
#     forward(120)  # Largeur
#     left(90)
#     forward(60)   # Hauteur
#     left(90)
# ```
#
# **Explication :** On alterne les deux dimensions.
# </details>
#
# ---

# %% [markdown]
# ### Exercice 3 : Le triangle équilatéral
#
# Dessinez un **triangle équilatéral** de côté **80 pixels**.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=250, height=200)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=250, height=200)
#
# for i in range(3):
#     forward(80)
#     left(120)
# ```
#
# **Explication :** L'angle de rotation est 360°/3 = 120°.
# </details>
#
# ---

# %% [markdown]
# ### Exercice 4 : L'hexagone
#
# Dessinez un **hexagone régulier** de côté **50 pixels**.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=250, height=220)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=250, height=220)
#
# for i in range(6):
#     forward(50)
#     left(60)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 5 : L'octogone
#
# Dessinez un **octogone régulier** de côté **45 pixels**.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=280, height=250)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=280, height=250)
#
# for i in range(8):
#     forward(45)
#     left(45)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 6 : Le losange
#
# Dessinez un **losange** de côté **70 pixels** (angles de 60° et 120°).
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=250, height=220)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=250, height=220)
#
# for i in range(2):
#     forward(70)
#     left(60)
#     forward(70)
#     left(120)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 7 : Le cercle (approximation)
#
# Dessinez un **cercle** en utilisant un polygone à 36 côtés de **8 pixels** chacun.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=260, height=260)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=260, height=260)
#
# for i in range(36):
#     forward(8)
#     left(10)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 8 : L'ennéagone (9 côtés)
#
# Dessinez un **ennéagone** (9 côtés) de côté **40 pixels**.
#
# **Figure attendue :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">

# %%
from jupyturtle import *
make_turtle(width=280, height=260)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=280, height=260)
#
# for i in range(9):
#     forward(40)
#     left(40)
# ```
# </details>
#
# ---

# %% [markdown]
# # 🎯 Partie 2 : Figures complexes
#
# **Consigne :** Observez la figure et retrouvez le code qui la produit. Des indices vous sont donnés pour les couleurs et dimensions.
#
# ---

# %% [markdown]
# ### Exercice 9 : Le carré multicolore
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Couleurs: <code>red</code>, <code>green</code>, <code>blue</code>, <code>orange</code>. Côté: 80 pixels. Épaisseur: 4.
# </div>

# %%
from jupyturtle import *
make_turtle(width=280, height=240)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=280, height=240)
#
# couleurs = ["red", "green", "blue", "orange"]
# set_width(4)
#
# for i in range(4):
#     set_color(couleurs[i])
#     forward(80)
#     left(90)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 10 : L'étoile à 5 branches
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Couleur: <code>gold</code>. Branches: 100 pixels. Angle: 144° (tournez à droite).
# </div>

# %%
from jupyturtle import *
make_turtle(width=320, height=280)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=320, height=280)
#
# set_color("gold")
# set_width(2)
#
# for i in range(5):
#     forward(100)
#     right(144)
# ```
#
# **Explication :** Pour une étoile à 5 branches, on tourne de 144° = 180° - 36°.
# </details>
#
# ---

# %% [markdown]
# ### Exercice 11 : L'escalier
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> 6 marches. Largeur: 30 pixels. Hauteur: 25 pixels.
# </div>

# %%
from jupyturtle import *
make_turtle(width=280, height=220)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=280, height=220)
#
# for i in range(6):
#     forward(30)   # Partie horizontale
#     left(90)
#     forward(25)   # Partie verticale
#     right(90)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 12 : Le flocon
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Couleur: <code>dodgerblue</code>. 6 branches de 50 pixels. Utilisez <code>back()</code> pour revenir au centre.
# </div>

# %%
from jupyturtle import *
make_turtle(width=260, height=260)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=260, height=260)
#
# set_color("dodgerblue")
# set_width(2)
#
# for i in range(6):
#     forward(50)   # Branche
#     back(50)      # Retour au centre
#     left(60)      # 360°/6 = 60°
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 13 : La maison
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Corps: carré de 70 pixels. Toit: triangle équilatéral de 70 pixels.
# </div>

# %%
from jupyturtle import *
make_turtle(width=300, height=280)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=300, height=280)
#
# # Corps (carré)
# for i in range(4):
#     forward(70)
#     left(90)
#
# # Monter au toit
# left(90)
# forward(70)
# right(30)
#
# # Toit (triangle)
# for i in range(3):
#     forward(70)
#     right(120)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 14 : La spirale carrée
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Longueur initiale: 5 pixels. Augmentation: +5 à chaque côté. Environ 28 côtés.
# </div>

# %%
from jupyturtle import *
make_turtle(width=380, height=380)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=380, height=380)
#
# longueur = 5
#
# for i in range(28):
#     forward(longueur)
#     left(90)
#     longueur = longueur + 5
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 15 : La rosace de carrés
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> 8 carrés de 50 pixels. Rotation de 45° entre chaque carré.
# </div>

# %%
from jupyturtle import *
make_turtle(width=320, height=320)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=320, height=320)
#
# for j in range(8):
#     # Dessiner un carré
#     for i in range(4):
#         forward(50)
#         left(90)
#     # Tourner pour le prochain carré
#     left(45)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 16 : La rosace de triangles
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Couleurs: <code>red</code>, <code>orange</code>, <code>yellow</code>, <code>green</code>, <code>blue</code>, <code>purple</code>. Triangles de 70 pixels.
# </div>

# %%
from jupyturtle import *
make_turtle(width=320, height=300)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=320, height=300)
#
# couleurs = ["red", "orange", "yellow", "green", "blue", "purple"]
#
# for i in range(6):
#     set_color(couleurs[i])
#     for j in range(3):
#         forward(70)
#         left(120)
#     left(60)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 17 : L'étoile de David
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Couleur: <code>royalblue</code>. 2 triangles de 80 pixels, décalés de 60°.
# </div>

# %%
from jupyturtle import *
make_turtle(width=300, height=280)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=300, height=280)
#
# set_color("royalblue")
# set_width(2)
#
# for k in range(2):
#     for i in range(3):
#         forward(80)
#         left(120)
#     left(60)
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 18 : La spirale triangulaire
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong> Angle: 120°. Longueur initiale: 5 pixels. Augmentation: +4. Environ 30 côtés.
# </div>

# %%
from jupyturtle import *
make_turtle(width=400, height=400)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=400, height=400)
#
# longueur = 5
#
# for i in range(30):
#     forward(longueur)
#     left(120)
#     longueur = longueur + 4
# ```
# </details>
#
# ---

# %% [markdown]
# ### Exercice 19 : La fleur à 8 pétales
#
# **Reproduisez cette figure :**
#
# <img src="data:image/png;base64,..." style="border: 1px solid #ddd; border-radius: 8px; padding: 10px; background: white; display: block; margin: 10px auto;">
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px; margin-top: 10px;">
# 💡 <strong>Indices :</strong>Couleurs arc-en-ciel: <code>red</code>, <code>orange</code>, <code>gold</code>, <code>limegreen</code>, <code>cyan</code>, <code>dodgerblue</code>, <code>purple</code>, <code>hotpink</code>.
# </div>

# %%
from jupyturtle import *
make_turtle(width=320, height=320)

# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# from jupyturtle import *
# make_turtle(width=320, height=320)
#
# couleurs = ["red", "orange", "gold", "limegreen", "cyan", "dodgerblue", "purple", "hotpink"]
# set_width(2)
#
# for i in range(8):
#     set_color(couleurs[i])
#     for j in range(2):
#         forward(40)
#         left(45)
#         forward(40)
#         left(135)
#     left(45)
# ```
# </details>
#
# ---

# %% [markdown]
# # 🏆 Challenge final
#
# ### Créez votre propre œuvre d'art !
#
# Créez un dessin original en combinant les techniques apprises. Votre création doit inclure :
# - Au moins 3 couleurs différentes
# - Au moins 2 types de formes
# - Au moins une boucle
# - Un motif répétitif ou une symétrie
#
# **Idées :** Mandala, paysage géométrique, symbole, illusion d'optique...

# %%
# Créez votre œuvre d'art ici !
from jupyturtle import *
make_turtle(width=400, height=400)

# Laissez libre cours à votre créativité...

# %% [markdown]
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Créer un nouveau dessin : `make_turtle()`
# - ✅ Déplacer la tortue : `forward()`, `back()`, `left()`, `right()`
# - ✅ Contrôler le stylo : `pen_up()`, `pen_down()`, `set_color()`, `set_width()`
# - ✅ Dessiner des polygones réguliers avec des boucles (angle = 360°/n)
# - ✅ Créer des motifs répétitifs : spirales, étoiles, rosaces
#
# ### 🔄 Correspondance avec turtle standard
#
# | jupyturtle | turtle standard |
# |------------|----------------|
# | `make_turtle()` | `turtle.Turtle()` |
# | `pen_up()` | `penup()` |
# | `pen_down()` | `pendown()` |
# | `set_color()` | `pencolor()` |
# | `set_width()` | `pensize()` |
#
# </div>
#
# ---
#
# <div style="background-color: #c8e6c9; padding: 15px; border-radius: 10px; text-align: center;">
#     <strong>🎉 Bravo ! Vous avez terminé cette activité !</strong><br>
#     Vous maîtrisez maintenant les bases du dessin avec turtle.
# </div>
