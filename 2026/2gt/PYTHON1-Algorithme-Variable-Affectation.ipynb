# %% [markdown]
# <style>
# .p1-doc kbd{background:#f1f5f9;border:1px solid #cbd5e1;border-bottom-width:2px;border-radius:4px;padding:0 .35em;font-size:.85em}
# @media print{.p1-doc details{border-color:#999}}
# </style>
#
# <div class="p1-doc"><div style="display:flex;gap:14px;align-items:center"><div style="flex:0 0 auto;width:2.6em;height:2.6em;border:2.5px solid #c00000;border-radius:50%;display:flex;align-items:center;justify-content:center;font:700 1.35rem/1 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#c00000">1</div><div style="border:2px solid #c00000;border-radius:5px;padding:.55em 1.1em;font:700 1.28rem/1.45 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#c00000">PYTHON 1 : Algorithme &ndash; Variable &ndash; Affectation</div></div></div>
#
# **Classe de seconde** &middot; séquence 1 &middot; durée : 1 h 30 à 2 h
#
# Voici un exemple d'algorithme, celui dont part tout le cours :
#
# <div style="display:inline-block;vertical-align:top;width:17em;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:italic 700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#1f2937;margin-bottom:.3em">Programme de calcul</div><div style="font:1rem/1.85 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; choisir un nombre<br>&bull; le multiplier par 3<br>&bull; ajouter 5<br>&bull; afficher le résultat</div></div>
#
# <div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128161; Comment travailler dans ce carnet</div>Ce carnet contient trois sortes de cellules.<ul style="margin:.4em 0 0;padding-left:1.3em"><li>Les <b>cellules grises</b> sont de vrais programmes : clique dedans et fais <kbd>Maj</kbd> + <kbd>Entrée</kbd> pour les exécuter.</li><li>Les cadres <b>Ta réponse</b> : double-clique dedans pour écrire, puis <kbd>Maj</kbd> + <kbd>Entrée</kbd> pour les refermer.</li><li>Les <b>volets verts</b> : l'explication complète, à n'ouvrir qu'après avoir cherché.</li></ul>Quand un exercice est terminé, appelle le professeur pour le vérifier avec toi.</div>
#
# <div style="border-left:5px solid #16a34a;background:#f0fdf4;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#16a34a;margin-bottom:.35em">&#128190; Pense à sauvegarder</div>Tes réponses sont écrites <b>dans le carnet</b>. Fais <kbd>Ctrl</kbd> + <kbd>S</kbd> de temps en temps, et tu les retrouveras au prochain cours.</div>

# %% [markdown]
# <div style="margin:1.6em 0 .7em;font:700 1.18rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#008000;border-bottom:2.5px solid #008000;display:inline-block;padding-bottom:.12em">I &ndash; Algorithme :</div>
#
# Un <b>algorithme</b> est une suite <span style="text-decoration:underline;text-underline-offset:.18em">finie</span> d'instructions (par exemple un programme de calcul) à appliquer dans un <span style="text-decoration:underline;text-underline-offset:.18em">ordre donné</span>, à un nombre <span style="text-decoration:underline;text-underline-offset:.18em">fini</span> de données, pour arriver à un résultat.
#
# Pour qu'un tel algorithme puisse être exécuté par un ordinateur, il faut le <span style="text-decoration:underline;text-underline-offset:.18em">traduire</span> dans un langage compréhensible par l'ordinateur. On appelle cela un <span style="text-decoration:underline;text-underline-offset:.18em">langage de programmation</span>. On utilisera <span style="text-decoration:underline;text-underline-offset:.18em">Python</span> au lycée.

# %% [markdown]
# <div style="margin:1.6em 0 .7em;font:700 1.18rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#008000;border-bottom:2.5px solid #008000;display:inline-block;padding-bottom:.12em">II &ndash; Variable :</div>
#
# Dans un programme, il faut souvent mémoriser des valeurs (un nombre, un mot, une réponse vrai ou faux&hellip;). On utilise pour cela une <b>variable</b> : c'est un emplacement de la mémoire de l'ordinateur et on lui donne un <b>nom</b> et une <b>valeur</b> d'un certain <b>type</b>.
#
# <div style="text-align:center;margin:1em 0"><img alt="Schéma : la mémoire de l'ordinateur, quatre variables nommées pointant chacune vers sa valeur" src="data:image/png;base64,..." style="width:100%;max-width:480px;height:auto;border:1px solid #94a3b8;border-radius:6px;background:#fff;padding:4px"><div style="font:italic .88rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#64748b;margin-top:.3em">Chaque nom de variable désigne une case de la mémoire.</div></div>
#
# <div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:100%;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Nom</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Valeur</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Type de variable</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Type en Python</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">age</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">15</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">nombre entier relatif</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">a</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">3.7</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">nombre décimal (valeur approchée)</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">reponse</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">True</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">booléen (vrai / faux)</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">bool</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">animal</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">"chaton"</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">chaine de caractères</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code></b></td></tr></tbody></table></div>
#
# Exécute la cellule suivante : Python affiche chaque valeur et son type.

# %%
# Les quatre variables du tableau, écrites cette fois en vrai Python.
age = 15
a = 3.7
reponse = True
animal = "chaton"

print(age, type(age))
print(a, type(a))
print(reponse, type(reponse))
print(animal, type(animal))

# %% [markdown]
# <div style="margin:1.6em 0 .7em;font:700 1.18rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#008000;border-bottom:2.5px solid #008000;display:inline-block;padding-bottom:.12em">III &ndash; Affectation :</div>
#
# <div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:100%;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Programme de calcul</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">En langage Python</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Valeur des variables</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; choisir le nombre 4</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000">b = <span style="color:#1a4fd0">4</span></span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif">b vaut <b style="color:#c00000">4</b></span></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; le multiplier par 2</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000">b = b * <span style="color:#1a4fd0">2</span></span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif">b vaut <b style="color:#c00000">8</b></span></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; ajouter 5</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000">b = b + <span style="color:#1a4fd0">5</span></span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif">b vaut <b style="color:#c00000">13</b></span></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; tester si résultat &lt; 10</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000">test = b &lt; <span style="color:#1a4fd0">10</span></span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif">test vaut <b style="color:#c00000">False</b></span></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; afficher le résultat</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000"><span style="color:#a000a0">print</span>(b)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; afficher le test</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000"><span style="color:#a000a0">print</span>(test)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&bull; afficher le mot &laquo;&nbsp;Merci&nbsp;&raquo;</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#c00000"><span style="color:#a000a0">print</span>(<span style="color:#0a8a2a">&quot;Merci&quot;</span>)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"></td></tr></tbody></table></div>
#
# <div style="font:1rem/1.9 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">&laquo;&nbsp;b&nbsp;&raquo; est une variable de type <b style="color:#c00000">int</b><br>&laquo;&nbsp;test&nbsp;&raquo; est une variable de type <b style="color:#c00000">bool</b></div>
#
# Après exécution, ce programme Python affiche à l'écran :
#
# <div style="position:relative;display:inline-block;vertical-align:top;width:9em;max-width:100%;margin:.95em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)"><span style="color:#1a4fd0">13</span><br><span style="color:#b35b00;font-weight:600">False</span><br>Merci</div><div style="position:absolute;top:-.68em;right:.8em;background:#fffdf6;color:#334155;font:600 .72rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;padding:.05em .55em;border:1px solid #94a3b8;border-radius:999px;white-space:nowrap">Écran</div></div>
#
# Exécute ce programme, qui traduit exactement le tableau ci-dessus.

# %%
# Le programme de la partie III, traduit en Python.
b = 4
b = b * 2
b = b + 5
test = b < 10

print(b)
print(test)
print("Merci")

# %% [markdown]
# <div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le point à retenir de cette partie</div>La ligne <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">b = b * 2</code> n'est pas une égalité mathématique : elle ne compare rien. Elle se lit <b>de droite à gauche</b> — on calcule ce qui est à droite, et on <b>range</b> le résultat dans le nom qui est à gauche. C'est pourquoi cette ligne n'a aucun sens en mathématiques, alors qu'elle en a un très précis ici : prendre la valeur actuelle de b, la doubler, et ranger le total dans b.</div>

# %% [markdown]
# <div style="margin:1.6em 0 .7em;font:700 1.18rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#008000;border-bottom:2.5px solid #008000;display:inline-block;padding-bottom:.12em">IV &ndash; Syntaxe et symboles à connaitre en Python :</div>
#
# <div style="margin:.5em 0 1em"><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">+</span>ajouter</span><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">-</span>soustraire</span><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">*</span>multiplier</span><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">/</span>diviser</span><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">**</span>puissance</span><span style="display:inline-flex;align-items:center;gap:.45em;margin:.2em 1.1em .2em 0;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="border:1.5px solid #1f2937;border-radius:3px;padding:0 .4em;font:600 .95rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#fffdf6">sqrt</span>racine carrée</span></div>
#
# <div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:100%;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Instruction Python</th><th style="border:1.3px solid #1f2937;background:#f8cbad;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">À quoi elle sert</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#a000a0">print</span>(a)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">pour afficher à l'écran la valeur de la variable a</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#a000a0">print</span>(<span style="color:#0a8a2a">&quot;Bonjour&quot;</span>)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">pour afficher à l'écran le mot : Bonjour</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#a000a0">input</span>(<span style="color:#0a8a2a">&quot;………&quot;</span>)</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">pour demander une valeur à l'utilisateur</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#a000a0">int</span>(<span style="color:#a000a0">input</span>(<span style="color:#0a8a2a">&quot;……&quot;</span>))</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">pour demander une valeur à l'utilisateur <u>et</u> dire que c'est de type entier (pour l'utiliser ensuite) et non pas chaine de caractères</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#a000a0">float</span>(<span style="color:#a000a0">input</span>(<span style="color:#0a8a2a">&quot;……&quot;</span>))</span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">pour demander une valeur à l'utilisateur et dire que c'est un nombre décimal (de type float)</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><span style="font:.95rem/1.6 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace"><span style="color:#b35b00;font-weight:600">from</span> math <span style="color:#b35b00;font-weight:600">import</span> <span style="color:#a000a0">sqrt</span></span></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">à écrire en début de programme pour utiliser &laquo;&nbsp;sqrt&nbsp;&raquo;</td></tr></tbody></table></div>
#
# Les six symboles, à l'essai.

# %%
from math import sqrt

print(7 + 2)
print(7 - 2)
print(7 * 2)
print(7 / 2)        # la division donne TOUJOURS un flottant
print(7 ** 2)       # la puissance : 7 au carré
print(sqrt(49))

# %% [markdown]
# <div style="margin:2.4em 0 1em;background:#fef08a;border-radius:7px;padding:.8em 1.1em;font:700 1.25rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#713f12;text-align:center;box-shadow:0 2px 6px rgba(113,63,18,.15)">EXERCICES</div>
#
# Cherche d'abord au brouillon, note ta réponse dans le cadre <b>Ta réponse</b>, puis exécute le programme pour vérifier.

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 1<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">traduire un algorithme, et nommer le type obtenu</span></div>
#
# <div style="max-width:20em"><div style="font:600 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155;margin-bottom:.15em">Algo 1</div><div style="display:inline-block;vertical-align:top;width:100%;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:1rem/1.9 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">a vaut 5<br>le multiplier par 2<br>lui soustraire 3<br>afficher le résultat</div></div></div>
#
# <div style="display:flex;align-items:flex-start;gap:.5em;margin:.5em 0;font:600 1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597"><span style="font-size:1.25em;color:#2f5597">&#8595;</span><span>Écris ce programme dans la cellule de code ci-dessous, puis exécute-le.</span></div>

# %%
a = 5
a = a * 2
# À toi : lui soustraire 3, puis afficher le résultat

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le programme affiche à la fin :** ......................
# >
# > **a est une variable Python de type :** ......................

# %% [markdown]
# <div style="max-width:20em"><div style="font:600 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155;margin-bottom:.15em">Algo 2</div><div style="display:inline-block;vertical-align:top;width:100%;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:1rem/1.9 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">b vaut 32<br>le diviser par 10<br>lui soustraire 1<br>afficher le résultat</div></div></div>
#
# <div style="display:flex;align-items:flex-start;gap:.5em;margin:.5em 0;font:600 1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597"><span style="font-size:1.25em;color:#2f5597">&#8595;</span><span>Écris ce programme dans la cellule de code ci-dessous, puis exécute-le.</span></div>

# %%
# À toi : les quatre lignes de l'algo 2

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le programme affiche à la fin :** ......................
# >
# > **b est une variable Python de type :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 1</summary><div style="margin-top:.6em"><div style="font-weight:700;margin:.2em 0">Algo 1</div><div style="position:relative;display:inline-block;vertical-align:top;width:14em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">a = <span style="color:#1a4fd0">5</span><br>a = a * <span style="color:#1a4fd0">2</span><br>a = a - <span style="color:#1a4fd0">3</span><br><span style="color:#a000a0">print</span>(a)</div></div><div>Affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">7</code>. La variable <b>a</b> est de type <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> : 5, 2 et 3 sont des entiers, et ni la multiplication ni la soustraction ne changent cela.</div><div style="height:.9em"></div><div style="font-weight:700;margin:.2em 0">Algo 2</div><div style="position:relative;display:inline-block;vertical-align:top;width:14em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">b = <span style="color:#1a4fd0">32</span><br>b = b / <span style="color:#1a4fd0">10</span><br>b = b - <span style="color:#1a4fd0">1</span><br><span style="color:#a000a0">print</span>(b)</div></div><div>Affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">2.2</code>. La variable <b>b</b> est de type <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code>.</div><div style="border-left:5px solid #dc2626;background:#fef2f2;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#dc2626;margin-bottom:.35em">&#128680; Le piège de cet exercice</div>C'est la <b>division</b> qui change le type, et elle le change <b>toujours</b> : <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">32 / 10</code> vaut <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">3.2</code>, pas <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">3</code>. Une fois la variable devenue flottante, elle le reste — la soustraction qui suit ne la ramène pas à un entier.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 2<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">demander son type à Python</span></div>
#
# Tes deux programmes tournent. Python sait dire lui-même de quel type est une variable : l'instruction <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">type(a)</code> le donne. Demande le type de <b>a</b> dans la cellule ci-dessous — pense à l'entourer d'un <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">print(...)</code> pour qu'il s'affiche.

# %%
# À toi : afficher le type de a

# %% [markdown]
# Fais maintenant la même chose pour <b>b</b>.

# %%
# À toi : afficher le type de b

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Pour a, Python répond :** ......................
# >
# > **Pour b, Python répond :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 2</summary><div style="margin-top:.6em">Python répond <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;class &#x27;int&#x27;&gt;</code> pour a et <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;class &#x27;float&#x27;&gt;</code> pour b.<div style="height:.5em"></div>L'instruction s'écrit <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">print(type(a))</code>. Sans le <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">print</code>, Python calcule bien le type mais ne l'affiche pas.<div style="height:.5em"></div>Le mot <i>class</i> est le vocabulaire de Python : un type y est une classe. Retiens seulement le nom entre guillemets.</div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 3<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">un test, et deux mots que l&#x27;on colle</span></div>
#
# <div style="max-width:20em"><div style="font:600 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155;margin-bottom:.15em">Algo 3</div><div style="display:inline-block;vertical-align:top;width:100%;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:1rem/1.9 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">n vaut 5<br>tester si n &gt; 7<br>afficher le résultat du test</div></div></div>
#
# La deuxième ligne range le résultat du test dans une variable appelée <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">test</code>.
#
# <div style="display:flex;align-items:flex-start;gap:.5em;margin:.5em 0;font:600 1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597"><span style="font-size:1.25em;color:#2f5597">&#8595;</span><span>Écris ce programme dans la cellule de code ci-dessous, puis exécute-le.</span></div>

# %%
# À toi : les trois lignes de l'algo 3

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le programme affiche à la fin :** ......................
# >
# > **n est une variable Python de type :** ......................
# >
# > **test est une variable Python de type :** ......................

# %% [markdown]
# <div style="max-width:20em"><div style="font:600 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155;margin-bottom:.15em">Algo 4</div><div style="display:inline-block;vertical-align:top;width:100%;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:1rem/1.9 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">mot vaut &laquo;&nbsp;ba&nbsp;&raquo;<br>lui rajouter ce mot<br>afficher le mot final</div></div></div>
#
# <div style="display:flex;align-items:flex-start;gap:.5em;margin:.5em 0;font:600 1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597"><span style="font-size:1.25em;color:#2f5597">&#8595;</span><span>Écris ce programme dans la cellule de code ci-dessous, puis exécute-le.</span></div>

# %%
# À toi : les trois lignes de l'algo 4

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le programme affiche à la fin :** ......................
# >
# > **mot est une variable Python de type :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 3</summary><div style="margin-top:.6em"><div style="font-weight:700;margin:.2em 0">Algo 3</div><div style="position:relative;display:inline-block;vertical-align:top;width:14em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">n = <span style="color:#1a4fd0">5</span><br>test = n &gt; <span style="color:#1a4fd0">7</span><br><span style="color:#a000a0">print</span>(test)</div></div><div>Affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">False</code>, car 5 n'est pas plus grand que 7. <b>n</b> est de type <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> et <b>test</b> de type <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">bool</code>.</div><div style="height:.9em"></div><div style="font-weight:700;margin:.2em 0">Algo 4</div><div style="position:relative;display:inline-block;vertical-align:top;width:15em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">mot = <span style="color:#0a8a2a">&quot;ba&quot;</span><br>mot = mot + mot<br><span style="color:#a000a0">print</span>(mot)</div></div><div>Affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">baba</code>. <b>mot</b> est de type <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code>.</div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le point à retenir</div>Le signe <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">+</code> fait deux choses très différentes selon ce qu'on lui donne. Entre deux nombres il <b>additionne</b> ; entre deux chaînes il <b>colle</b> (on dit : il concatène). C'est pour cela que <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&quot;7&quot; + &quot;7&quot;</code> vaut <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&quot;77&quot;</code> et non 14.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 4<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">demander son type à Python, encore</span></div>
#
# Comme à l'exercice 2, affiche le type des trois variables que tu viens de créer : <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">n</code>, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">test</code> et <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">mot</code>.

# %%
# À toi : afficher le type de n, de test et de mot

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **n est de type :** ......................
# >
# > **test est de type :** ......................
# >
# > **mot est de type :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 4</summary><div style="margin-top:.6em">Python répond <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;class &#x27;int&#x27;&gt;</code> pour <b>n</b>, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;class &#x27;bool&#x27;&gt;</code> pour <b>test</b> et <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;class &#x27;str&#x27;&gt;</code> pour <b>mot</b>.<div style="height:.5em"></div>Une seule ligne suffit : <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">print(type(n), type(test), type(mot))</code>.</div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 5<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">prévoir de tête, puis vérifier</span></div>
#
# Pour chacun des quatre programmes qui suivent : <b>lis-le sans l'exécuter</b>, note ta prévision, et exécute-le seulement ensuite.

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 1</div>

# %%
x = 10
y = 20
z = x * y
z = z + x
print(z)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Je prévois que ce programme affiche :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 2</div>

# %%
n = 4
n = 3 * n
n = n + 8
n = n / 2
print(n)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Je prévois que ce programme affiche :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 3</div>

# %%
a = 5
b = 4
c = a * 3 + b ** 2
print(c)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Je prévois que ce programme affiche :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 4</div>

# %%
from math import sqrt
AB = 3
AC = 4
BC2 = AB ** 2 + AC ** 2
BC = sqrt(BC2)
print(BC)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Je prévois que ce programme affiche :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 5</summary><div style="margin-top:.6em"><div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:100%;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Programme</th><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Affiche</th><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Pourquoi</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">1</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">210</code></b></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">z prend d'abord 200, puis 200 + 10. Tout reste entier.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">2</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">10.0</code></b></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">12, puis 20, puis 20 / 2. La division fait apparaître le point décimal.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">3</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">31</code></b></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">15 + 16. La puissance passe avant la multiplication, qui passe avant l'addition.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">4</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">5.0</code></b></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">9 + 16 = 25, puis la racine carrée de 25. C'est le théorème de Pythagore.</td></tr></tbody></table></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Ce que ces quatre programmes ont à t&#x27;apprendre</div>Deux programmes sur quatre affichent un nombre à virgule alors qu'aucun nombre à virgule n'est écrit dans le programme. Dans les deux cas, c'est une <b>division</b> ou une <b>racine carrée</b> qui l'a introduit. Retiens la règle : <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">/</code> donne toujours un <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code>.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 6<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">poser une question avec input</span></div>
#
# Utilisons la fonction toute prête <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">input</code> pour poser une question et stocker la réponse.
#
# <div style="border-left:5px solid #0891b2;background:#ecfeff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Quand tu exécutes une cellule contenant <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">input</code>, une zone de saisie apparaît sous la cellule : tape ta réponse puis fais <kbd>Entrée</kbd>. Tant que tu n'as pas répondu, la cellule reste en attente.</div>
#
# <div style="font-weight:700;margin:.2em 0">Programme 1</div>
#
# Exécute-le, réponds à la question, puis note ce que tu as observé.

# %%
prenom = input("Quel est ton prénom ? ")
message = "Bonjour " + prenom
print(message)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **La question posée est :** ......................
# >
# > **Le programme affiche à la fin :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 2</div>
#
# Même travail.

# %%
age = int(input("Quel est ton âge ? "))
annee = 2026 - age
print("Tu es né(e) en", annee)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **La question posée est :** ......................
# >
# > **Le programme affiche à la fin :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Programme 2, privé de son <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code></div>
#
# Exécute cette version, réponds à la question, et lis le message d'erreur en entier.

# %%
age = input("Quel est ton âge ? ")
annee = 2026 - age
print("Tu es né(e) en", annee)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le nom de l'erreur :** ......................
# >
# > **Ce qui se passe quand on enlève le int :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 6</summary><div style="margin-top:.6em"><b>Programme 1.</b> La question posée est <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">Quel est ton prénom ?</code>. Si tu réponds <i>Alice</i>, le programme affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">Bonjour Alice</code>.<div style="height:.6em"></div><b>Programme 2.</b> La question posée est <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">Quel est ton âge ?</code>. Si tu réponds <i>16</i>, le programme affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">Tu es né(e) en 2010</code>.<div style="height:.6em"></div><div style="margin-bottom:.2em"><b>Sans le <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code></b>, le programme s'arrête sur une erreur nommée <b>TypeError</b> :</div><div style="position:relative;display:inline-block;vertical-align:top;width:100%;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">TypeError: unsupported operand <span style="color:#a000a0">type</span>(s) <span style="color:#b35b00;font-weight:600">for</span> -: <span style="color:#0a8a2a">&#x27;int&#x27;</span> <span style="color:#b35b00;font-weight:600">and</span> <span style="color:#0a8a2a">&#x27;str&#x27;</span></div></div><div style="border-left:5px solid #dc2626;background:#fef2f2;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#dc2626;margin-bottom:.35em">&#128680; Pourquoi ce int est indispensable</div><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">input</code> renvoie <b>toujours</b> une chaîne de caractères, même quand on tape des chiffres : la réponse <i>16</i> arrive comme <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&quot;16&quot;</code>, et non comme le nombre 16. Or on ne peut pas soustraire un mot à un nombre. Le rôle de <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int(...)</code> est de convertir cette chaîne en entier, pour qu'on puisse calculer avec.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 7<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">choisir le type d&#x27;une variable</span></div>
#
# Pour ranger chacune de ces informations dans une variable, quel type choisirais-tu ?<ul style="margin:.5em 0 0;padding-left:1.3em;font:1rem/1.8 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><li>l'âge d'un élève ;</li><li>sa taille en mètres ;</li><li>son prénom ;</li><li>le code postal de Bar-sur-Aube (10200) ;</li><li>la réponse à « As-tu un animal ? ».</li></ul>

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Âge de l'élève :** ......................
# >
# > **Taille en mètres :** ......................
# >
# > **Prénom :** ......................
# >
# > **Code postal de Bar-sur-Aube :** ......................
# >
# > **Réponse à « As-tu un animal ? » :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 7 (partie a)</summary><div style="margin-top:.6em"><div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:auto;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Information</th><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Type choisi</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">l'âge d'un élève</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">sa taille en mètres</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">son prénom</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">le code postal de Bar-sur-Aube</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">la réponse à « As-tu un animal ? »</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">bool</code></b></td></tr></tbody></table></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le piège du code postal</div>Un code postal se choisit en <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code>, et non en <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> : on ne calcule jamais avec lui (additionner deux codes postaux n'a aucun sens), et certains commencent par un zéro, comme 01000 pour Bourg-en-Bresse. Python refuse d'ailleurs d'écrire un entier <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">01000</code> : le zéro de tête n'est pas autorisé dans un nombre entier.</div></div></details>

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Partie b — une conversion mal choisie</div>
#
# Exécute ce programme, et réponds <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">1.75</code> (avec un point, pas une virgule) quand il te demande ta taille.

# %%
taille = int(input("Quelle est ta taille en mètres ? "))
print("Tu mesures", taille * 100, "cm")

# %% [markdown]
# Lis le message d'erreur en entier, puis corrige toi-même le programme dans la cellule ci-dessous, en choisissant le bon type pour la conversion.

# %%
# À toi : corrige la conversion, puis exécute avec 1.75 comme réponse

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le nom de l'erreur :** ......................
# >
# > **Ce que j'ai changé :** ......................
# >
# > **Ce qu'affiche le programme corrigé :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 7 (partie b)</summary><div style="margin-top:.6em"><div>L'erreur se nomme <b>ValueError</b> :</div><div style="position:relative;display:inline-block;vertical-align:top;width:100%;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">ValueError: invalid literal <span style="color:#b35b00;font-weight:600">for</span> <span style="color:#a000a0">int</span>() with base <span style="color:#1a4fd0">10</span>: <span style="color:#0a8a2a">&#x27;1.75&#x27;</span></div></div><div style="height:.6em"></div><div><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> ne sait convertir que des chiffres sans virgule : il faut remplacer <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int(input(...))</code> par <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float(input(...))</code>. Avec 1.75, le programme corrigé affiche :</div><div style="position:relative;display:inline-block;vertical-align:top;width:100%;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">Tu mesures <span style="color:#1a4fd0">175.0</span> cm</div></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le point à retenir</div>Choisir le type, c'est se demander ce qu'on va faire de la valeur : compter (<b>int</b>), mesurer (<b>float</b>), écrire ou identifier (<b>str</b>), répondre oui ou non (<b>bool</b>).</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 8<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">de la flèche du langage naturel au signe = de Python</span></div>
#
# <div style="max-width:20em"><div style="font:600 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155;text-decoration:underline;margin-bottom:.15em">Instructions</div><div style="display:inline-block;vertical-align:top;width:100%;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:600 1rem/2 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">a <span style="font-size:1.05em">&#8592;</span> 1,4<br>a <span style="font-size:1.05em">&#8592;</span> a &times; 2<br>b <span style="font-size:1.05em">&#8592;</span> 3<br>b <span style="font-size:1.05em">&#8592;</span> b&nbsp;&sup2;<br>test <span style="font-size:1.05em">&#8592;</span> a &lt; b<br>afficher test</div></div></div>
#
# <div style="border-left:5px solid #0891b2;background:#ecfeff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">La flèche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;-</code> du langage naturel se traduit par le signe <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">=</code> de Python. Attention aux deux notations qui n'existent pas au clavier : &times; s'écrit <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">*</code>, et le petit 2 en exposant s'écrit <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">** 2</code>.</div>
#
# <div style="display:flex;align-items:flex-start;gap:.5em;margin:.5em 0;font:600 1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597"><span style="font-size:1.25em;color:#2f5597">&#8595;</span><span>Écris ce programme dans la cellule de code ci-dessous, puis exécute-le.</span></div>

# %%
# À toi : traduis les six instructions

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Le programme affiche :** ......................
# >
# > **a est de type :** ......................
# >
# > **b est de type :** ......................
# >
# > **test est de type :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 8</summary><div style="margin-top:.6em"><div style="position:relative;display:inline-block;vertical-align:top;width:16em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">a = <span style="color:#1a4fd0">1.4</span><br>a = a * <span style="color:#1a4fd0">2</span><br>b = <span style="color:#1a4fd0">3</span><br>b = b ** <span style="color:#1a4fd0">2</span><br>test = a &lt; b<br><span style="color:#a000a0">print</span>(test)</div></div><div>Le programme affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">True</code>. En effet a vaut 2,8 et b vaut 9, donc a est bien plus petit que b.</div><div style="height:.6em"></div><div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:auto;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Variable</th><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Valeur finale</th><th style="border:1.3px solid #1f2937;background:#dcfce7;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">Type</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">a</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">2.8</code></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">b</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">9</code></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code></b></td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">test</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">True</code></td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:center;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><b><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">bool</code></b></td></tr></tbody></table></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Trois types dans six lignes</div><b>a</b> est un flottant parce que 1,4 en est un dès le départ — ici, aucune division n'a été nécessaire. <b>b</b> reste un entier : la puissance d'un entier est un entier. Et le résultat d'une comparaison n'est jamais un nombre, c'est un booléen.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 9<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">une affectation a lieu une fois</span></div>
#
# Lis ce programme sans l'exécuter :

# %%
x = 3
y = x + 1
x = 10
print(y)

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Je prévois que ce programme affiche :** ......................
# >
# > **Ma réécriture en langage naturel, avec des flèches ← :** ......................

# %% [markdown]
# <div style="font-weight:700;margin:.2em 0">Pour aller plus loin : échanger deux variables</div>
#
# Essaie d'abord <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">a = b</code> puis <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">b = a</code> dans la cellule ci-dessous, exécute, et observe pourquoi <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">print(a, b)</code> n'affiche pas <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">8 5</code>. Puis trouve comment échanger vraiment les deux valeurs, à l'aide d'une troisième variable.

# %%
a = 5
b = 8
# À toi : échange les valeurs de a et b, pour que print(a, b) affiche 8 5
print(a, b)

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 9</summary><div style="margin-top:.6em"><div style="font-weight:700;margin:.2em 0">Une affectation a lieu une fois</div><div>Le programme affiche <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">4</code>, et non 11. La ligne <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">y = x + 1</code> a déjà été exécutée quand x valait 3 : y vaut alors 4, une fois pour toutes. Changer x ensuite ne recalcule pas y.</div><div style="height:.5em"></div><div>En langage naturel :</div><div style="display:inline-block;vertical-align:top;width:14em;max-width:100%;border:1.5px solid #1f2937;background:#ffffff;border-radius:4px;padding:.6em .85em;margin:.3em 0;text-align:left;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif"><div style="font:600 1rem/2 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">x &#8592; 3<br>y &#8592; x + 1<br>x &#8592; 10<br>afficher y</div></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le point à retenir</div>Une affectation a lieu <b>une fois</b>, au moment précis où sa ligne est lue. Ce qui se passe ensuite sur d'autres lignes ne la modifie jamais après coup.</div><div style="height:.9em"></div><div style="font-weight:700;margin:.2em 0">Échanger deux variables</div><div><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">a = b</code> écrase la valeur 5, qui est perdue : on obtient <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">8 8</code>, et non <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">8 5</code>. La solution utilise une troisième variable, qui garde une copie de a le temps de l'échange :</div><div style="position:relative;display:inline-block;vertical-align:top;width:14em;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">c = a<br>a = b<br>b = c<br><span style="color:#a000a0">print</span>(a, b)</div></div><div>Python permet aussi l'écriture <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">a, b = b, a</code>, en une seule ligne — mais la version à trois variables montre mieux ce qui se passe réellement.</div></div></details>

# %% [markdown]
# <div style="margin:2em 0 .8em;background:linear-gradient(95deg,#2f5597,#1e3a5f);color:#fff;border-radius:7px;padding:.5em 1em;font:700 1.1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;box-shadow:0 2px 6px rgba(47,85,151,.28)">Exercice 10<span style="font:400 .95rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#e2e8f0;margin-left:.7em">écrire un programme seul</span></div>
#
# Écris un programme qui demande à l'utilisateur la longueur et la largeur d'un rectangle, en mètres, puis affiche son périmètre et son aire. Cette fois, aucun algorithme n'est fourni : c'est à toi de choisir les variables, leur type, et l'ordre des lignes.

# %%
# À toi : demande la longueur et la largeur, puis affiche le périmètre et l'aire

# %% [markdown]
# > ✏️ **Ta réponse** — double-clique dans ce cadre pour écrire, puis `Maj` + `Entrée`.
# >
# > **Pour une longueur de 2.5 et une largeur de 4, mon programme affiche :** ......................

# %% [markdown]
# <details style="border:1.5px solid #16a34a;background:#f0fdf4;border-radius:7px;padding:.55em .9em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><summary style="cursor:pointer;font-weight:700;color:#15803d">Vérifier ma réponse — exercice 10</summary><div style="margin-top:.6em"><div style="position:relative;display:inline-block;vertical-align:top;width:100%;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">longueur = <span style="color:#a000a0">float</span>(<span style="color:#a000a0">input</span>(<span style="color:#0a8a2a">&quot;Longueur du rectangle, en m : &quot;</span>))<br>largeur = <span style="color:#a000a0">float</span>(<span style="color:#a000a0">input</span>(<span style="color:#0a8a2a">&quot;Largeur du rectangle, en m : &quot;</span>))<br>perimetre = <span style="color:#1a4fd0">2</span> * (longueur + largeur)<br>aire = longueur * largeur<br><span style="color:#a000a0">print</span>(<span style="color:#0a8a2a">&quot;Le périmètre du rectangle est&quot;</span>, perimetre, <span style="color:#0a8a2a">&quot;m&quot;</span>)<br><span style="color:#a000a0">print</span>(<span style="color:#0a8a2a">&quot;L&#x27;aire du rectangle est&quot;</span>, aire, <span style="color:#0a8a2a">&quot;m²&quot;</span>)</div></div><div>Pour une longueur de 2.5 et une largeur de 4, ce programme affiche :</div><div style="position:relative;display:inline-block;vertical-align:top;width:100%;max-width:100%;margin:.35em 0 .4em"><div style="background:#fffdf6;border:1.5px solid #1f2937;border-radius:7px;padding:.75em .9em;font:.92rem/1.65 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;color:#1f2937;white-space:pre;text-align:left;overflow-x:auto;box-shadow:2px 2px 0 rgba(31,41,55,.13)">Le périmètre du rectangle est <span style="color:#1a4fd0">13.0</span> m<br>L&#x27;aire du rectangle est <span style="color:#1a4fd0">10.0</span> m²</div></div><div style="border-left:5px solid #2f5597;background:#eff6ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#2f5597;margin-bottom:.35em">&#128273; Le point à retenir</div><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code> et non <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> : une longueur est une mesure, pas forcément un nombre entier. Les deux formules combinent chacune deux variables : le périmètre a besoin de la longueur <b>et</b> de la largeur, tout comme l'aire.</div></div></details>

# %% [markdown]
# <div style="margin:2.4em 0 1em;background:linear-gradient(95deg,#065f46,#047857);color:#fff;border-radius:7px;padding:.7em 1.1em;font:700 1.2rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif">Ce que je retiens de PYTHON 1</div>
#
# <div style="overflow-x:auto;margin:.7em 0"><table style="border-collapse:collapse;width:100%;box-shadow:2px 2px 0 rgba(31,41,55,.1)"><thead><tr><th style="border:1.3px solid #1f2937;background:#a7f3d0;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">À retenir</th><th style="border:1.3px solid #1f2937;background:#a7f3d0;padding:.45em .8em;font:700 .97rem/1.4 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;text-align:center;color:#1f2937">En une phrase</th></tr></thead><tbody><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Affectation</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">=</code> ne compare rien : on calcule la droite, on <b>range</b> dans la gauche.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Ordre des lignes</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">une affectation a lieu <b>une fois</b>, au moment où sa ligne est lue.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Les quatre types</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int</code> entier exact, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code> nombre à virgule, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">str</code> chaîne de caractères, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">bool</code> vrai ou faux.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Choisir le type</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">on se demande ce qu'on fera de la valeur : compter, mesurer, écrire, répondre oui/non.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Le piège n&deg;1</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">la division <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">/</code> donne <b>toujours</b> un <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">float</code>, même quand le quotient tombe juste.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Le piège n&deg;2</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">entre deux chaînes, <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">+</code> ne calcule pas : il <b>colle</b>.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Le piège n&deg;3</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">input</code> rend une chaîne ; sans <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">int(...)</code>, impossible de calculer avec la réponse.</td></tr><tr><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155">Comparer, c'est répondre</td><td style="border:1.3px solid #1f2937;padding:.42em .8em;text-align:left;font:1rem/1.6 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">&lt;</code> ou <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">==</code> ne donnent pas un nombre mais un booléen <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">True</code> ou <code style="font:.93rem/1.5 ui-monospace, 'Cascadia Mono', 'JetBrains Mono', Consolas, 'DejaVu Sans Mono', monospace;background:#f1f5f9;border:1px solid #e2e8f0;border-radius:4px;padding:.05em .35em;color:#1f2937">False</code>.</td></tr></tbody></table></div>
#
# <div style="border-left:5px solid #7c3aed;background:#f5f3ff;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#7c3aed;margin-bottom:.35em">&#127919; Avant l&#x27;interro</div>Pour t'entraîner, reprends les exercices 1, 3, 8 et 9 <b>sans regarder</b> les volets verts : ce sont exactement les gestes évalués à l'interro &mdash; lire un script et nommer le type de ses variables (exercices 1 et 3), traduire un programme de calcul (exercice 8), et prévoir ce qu'affiche un script après une réaffectation (exercice 9).</div>
#
# <div style="border-left:5px solid #16a34a;background:#f0fdf4;border-radius:0 7px 7px 0;padding:.75em 1em;margin:.9em 0;font:1rem/1.7 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#334155"><div style="font:700 1rem/1.5 'Segoe UI', system-ui, -apple-system, 'Helvetica Neue', Arial, sans-serif;color:#16a34a;margin-bottom:.35em">&#128190; Avant de fermer</div>Fais <kbd>Ctrl</kbd> + <kbd>S</kbd> : tes réponses sont écrites dans le carnet, elles seront là au prochain cours.</div>
