# %% [markdown]
# # 📘 Utiliser Python pour effectuer des calculs
#
# **Niveau** : Seconde
# **Thème mathématique** : Nombres et calculs
# **Durée estimée** : 30-45 min
#
# ## 🎯 Objectifs
#
# À la fin de cette activité, vous serez capable de :
# - Utiliser Python comme une calculatrice avec les opérateurs de base
# - Comprendre et appliquer les priorités opératoires
# - Effectuer des divisions euclidiennes
# - Afficher des résultats avec `print()`
# - Utiliser des fonctions mathématiques simples

# %% [markdown]
# ---
#
# ## 📚 Notion 1 : Les opérateurs arithmétiques de base
#
# ### 📖 Cours
#
# Python utilise les opérateurs suivants pour effectuer des calculs :
# - `+` : addition
# - `-` : soustraction
# - `*` : multiplication
# - `/` : division (résultat décimal)
# - `**` : puissance
#
# **Exemple résolu :**

# %%
# Addition
5 + 3

# %%
# Soustraction
10 - 7

# %%
# Multiplication
6 * 4

# %%
# Division
15 / 3

# %%
# Puissance : 2 à la puissance 5
2 ** 5

# %% [markdown]
# ### ✅ Vérification : QCM
#
# **Question 1 :** Quel est le résultat de `7 * 6` en Python ?
# - A) 13
# - B) 42
# - C) 76
#
# **Question 2 :** Quel opérateur utilise-t-on pour calculer $3^4$ ?
# - A) `3 * 4`
# - B) `3 ^ 4`
# - C) `3 ** 4`
#
# **Question 3 :** Quel est le résultat de `20 / 4` ?
# - A) `5`
# - B) `5.0`
# - C) `4`
#
# <details>
# <summary>✅ Correction</summary>
#
# **Question 1 :** B) 42
# **Explication :** 7 × 6 = 42
#
# **Question 2 :** C) `3 ** 4`
# **Explication :** En Python, l'opérateur `**` sert à calculer les puissances.
#
# **Question 3 :** B) `5.0`
# **Explication :** L'opérateur `/` donne toujours un résultat décimal (avec un point), même si le résultat est un nombre entier.
# </details>

# %% [markdown]
# ### 🔍 Exercice 1 : Comprendre un programme
#
# **Que fait le programme suivant ?**

# %%
12 + 8 * 2

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# Ce programme calcule l'expression `12 + 8 * 2`.
# Résultat : **28**
#
# **Attention :** Python respecte les priorités opératoires. La multiplication est effectuée en premier : `8 * 2 = 16`, puis l'addition : `12 + 16 = 28`.
# </details>

# %% [markdown]
# ### 💡 Exercice 2 : Application
#
# **A) Calculez les expressions suivantes :**
#
# 1. $15 + 23$
# 2. $50 - 18$
# 3. $7 \times 9$
# 4. $64 \div 8$
# 5. $5^3$

# %%
# Écrivez votre code ici

# %% [markdown]
# **B) Écrivez un programme qui calcule :**
#
# Le carré de 12 (c'est-à-dire $12^2$)
#
# *Indice : Utilisez l'opérateur de puissance.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction A</summary>
#
# ```python
# 15 + 23  # 38
# 50 - 18  # 32
# 7 * 9    # 63
# 64 / 8   # 8.0
# 5 ** 3   # 125
# ```
# </details>
#
# <details>
# <summary>💡 Correction B</summary>
#
# ```python
# 12 ** 2  # 144
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📚 Notion 2 : Priorités opératoires et parenthèses
#
# ### 📖 Cours
#
# Python respecte les **priorités opératoires** (comme en mathématiques) :
# 1. **Parenthèses** `()`
# 2. **Puissances** `**`
# 3. **Multiplication et Division** `*` `/` (de gauche à droite)
# 4. **Addition et Soustraction** `+` `-` (de gauche à droite)
#
# **Exemple résolu :**

# %%
# Sans parenthèses : multiplication d'abord
3 + 5 * 2

# %%
# Avec parenthèses : addition d'abord
(3 + 5) * 2

# %%
# Calcul complexe : (5² - 3) / 2
(5**2 - 3) / 2

# %% [markdown]
# ### ✅ Vérification : QCM
#
# **Question 1 :** Quel est le résultat de `10 - 4 * 2` ?
# - A) 12
# - B) 2
# - C) 8
#
# **Question 2 :** Comment calculer $(8 + 2) \times 3$ en Python ?
# - A) `8 + 2 * 3`
# - B) `(8 + 2) * 3`
# - C) `8 + (2 * 3)`
#
# <details>
# <summary>✅ Correction</summary>
#
# **Question 1 :** B) 2
# **Explication :** Python effectue d'abord `4 * 2 = 8`, puis `10 - 8 = 2`.
#
# **Question 2 :** B) `(8 + 2) * 3`
# **Explication :** Les parenthèses forcent Python à calculer d'abord l'addition.
# </details>

# %% [markdown]
# ### 🔍 Exercice 3 : Comprendre deux programmes
#
# **Comparez les deux programmes suivants. Donnent-ils le même résultat ? Pourquoi ?**
#
# **Programme A :**

# %%
6 + 4 / 2

# %% [markdown]
# **Programme B :**

# %%
(6 + 4) / 2

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# **Non, ils donnent des résultats différents !**
#
# - **Programme A** : `6 + 4 / 2 = 6 + 2 = 8.0` (la division est prioritaire)
# - **Programme B** : `(6 + 4) / 2 = 10 / 2 = 5.0` (les parenthèses forcent l'addition en premier)
#
# Les parenthèses changent l'ordre des opérations.
# </details>

# %% [markdown]
# ### 💡 Exercice 4 : Application
#
# **A) Calculez les expressions suivantes en utilisant des parenthèses si nécessaire :**
#
# 1. $2 + 3 \times 4$
# 2. $(2 + 3) \times 4$
# 3. $\dfrac{20 + 10}{5}$
# 4. $\dfrac{8^2 - 14}{10}$

# %%
# Écrivez votre code ici

# %% [markdown]
# **B) Écrivez un programme qui calcule :**
#
# La moyenne de trois nombres : 15, 18 et 21
#
# *Indice : La moyenne se calcule en additionnant les nombres puis en divisant par leur quantité.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction A</summary>
#
# ```python
# 2 + 3 * 4          # 14
# (2 + 3) * 4        # 20
# (20 + 10) / 5      # 6.0
# (8**2 - 14) / 10   # 5.0
# ```
# </details>
#
# <details>
# <summary>💡 Correction B</summary>
#
# ```python
# (15 + 18 + 21) / 3  # 18.0
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📚 Notion 3 : Division euclidienne
#
# ### 📖 Cours
#
# Python propose deux opérateurs pour la **division euclidienne** :
# - `//` : donne le **quotient**
# - `%` : donne le **reste**
#
# **Rappel** : Dans une division euclidienne, on a : **dividende = diviseur × quotient + reste**
#
# **Exemple résolu : Division euclidienne de 17 par 5**

# %%
# Quotient
17 // 5

# %%
# Reste
17 % 5

# %%
# Vérification : 17 = 5 × 3 + 2
5 * 3 + 2

# %% [markdown]
# ### ✅ Vérification : QCM
#
# **Question 1 :** Quel est le quotient de la division euclidienne de 23 par 4 ?
# - A) 5
# - B) 5.75
# - C) 3
#
# **Question 2 :** Quel opérateur utilise-t-on pour obtenir le reste d'une division euclidienne ?
# - A) `/`
# - B) `//`
# - C) `%`
#
# **Question 3 :** Quel est le reste de la division euclidienne de 29 par 6 ?
# - A) 4
# - B) 5
# - C) 6
#
# <details>
# <summary>✅ Correction</summary>
#
# **Question 1 :** A) 5
# **Explication :** 23 ÷ 4 = 5 reste 3, donc le quotient est 5.
#
# **Question 2 :** C) `%`
# **Explication :** L'opérateur `%` (modulo) donne le reste de la division euclidienne.
#
# **Question 3 :** B) 5
# **Explication :** 29 = 6 × 4 + 5, donc le reste est 5.
# </details>

# %% [markdown]
# ### 🔍 Exercice 5 : Comprendre un programme
#
# **Que calcule le programme suivant et quel est son résultat ?**

# %%
50 % 7

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# Ce programme calcule le **reste de la division euclidienne** de 50 par 7.
# Résultat : **1**
#
# Vérification : 50 = 7 × 7 + 1
# </details>

# %% [markdown]
# ### 💡 Exercice 6 : Application
#
# **A) Effectuez la division euclidienne de 38 par 5 :**
#
# Calculez le quotient et le reste.

# %%
# Écrivez votre code ici

# %% [markdown]
# **B) Écrivez un programme qui vérifie si 42 est divisible par 6**
#
# *Indice : Un nombre est divisible par un autre si le reste de leur division euclidienne est 0.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction A</summary>
#
# ```python
# 38 // 5  # Quotient : 7
# 38 % 5   # Reste : 3
# ```
# </details>
#
# <details>
# <summary>💡 Correction B</summary>
#
# ```python
# 42 % 6  # Résultat : 0 → donc 42 est divisible par 6
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📚 Notion 4 : Afficher des résultats avec print()
#
# ### 📖 Cours
#
# La fonction `print()` permet d'**afficher du texte et des résultats** de calculs.
#
# **Syntaxe :**
# - `print("texte")` : affiche du texte (entre guillemets)
# - `print(calcul)` : affiche le résultat d'un calcul
# - `print("texte", calcul)` : affiche du texte et un résultat (séparés par une virgule)
#
# **Exemple résolu :**

# %%
# Afficher un message
print("Bonjour !")

# %%
# Afficher un résultat de calcul
print(5 + 3)

# %%
# Afficher du texte et un résultat
print("Le résultat de 5 + 3 est :", 5 + 3)

# %% [markdown]
# ### ✅ Vérification : QCM
#
# **Question 1 :** Que fait `print("Python")` ?
# - A) Affiche le nombre Python
# - B) Affiche le mot Python
# - C) Calcule Python
#
# **Question 2 :** Comment afficher "Résultat : 12" en Python ?
# - A) `print(Résultat : 12)`
# - B) `print("Résultat :", 12)`
# - C) `print("Résultat : 12")`
#
# <details>
# <summary>✅ Correction</summary>
#
# **Question 1 :** B) Affiche le mot Python
# **Explication :** Les guillemets indiquent qu'on affiche du texte.
#
# **Question 2 :** B) `print("Résultat :", 12)` **OU** C) `print("Résultat : 12")`
# **Explication :** Les deux syntaxes fonctionnent. La B est préférable si on veut mélanger texte et calculs.
# </details>

# %% [markdown]
# ### 🔍 Exercice 7 : Comprendre un programme
#
# **Qu'affiche le programme suivant ?**

# %%
print("3 au carré =", 3**2)
print("4 au carré =", 4**2)

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# Ce programme affiche :
# ```
# 3 au carré = 9
# 4 au carré = 16
# ```
#
# Chaque `print()` affiche du texte suivi du résultat du calcul.
# </details>

# %% [markdown]
# ### 💡 Exercice 8 : Application
#
# **A) Affichez les puissances de 2 de $2^1$ à $2^4$ avec un message.**
#
# Format attendu : `2 puissance 1 = 2`, `2 puissance 2 = 4`, etc.

# %%
# Écrivez votre code ici

# %% [markdown]
# **B) Écrivez un programme qui affiche le quotient et le reste de la division de 50 par 7**
#
# *Indice : Utilisez `print()` deux fois, une pour le quotient et une pour le reste.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction A</summary>
#
# ```python
# print("2 puissance 1 =", 2**1)
# print("2 puissance 2 =", 2**2)
# print("2 puissance 3 =", 2**3)
# print("2 puissance 4 =", 2**4)
# ```
# </details>
#
# <details>
# <summary>💡 Correction B</summary>
#
# ```python
# print("Quotient :", 50 // 7)
# print("Reste :", 50 % 7)
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📚 Notion 5 : Fonctions mathématiques simples
#
# ### 📖 Cours
#
# Python dispose de fonctions mathématiques intégrées :
# - `abs(x)` : valeur absolue de x
# - `round(x)` : arrondi de x à l'entier le plus proche
# - `round(x, n)` : arrondi de x à n décimales
# - `pow(x, n)` : x puissance n (équivalent à `x**n`)
#
# **Exemple résolu :**

# %%
# Valeur absolue de -15
abs(-15)

# %%
# Arrondi de 3.7
round(3.7)

# %%
# Arrondi de π à 2 décimales
round(3.14159, 2)

# %%
# 2 puissance 8 avec pow
pow(2, 8)

# %% [markdown]
# ### ✅ Vérification : QCM
#
# **Question 1 :** Quel est le résultat de `abs(-20)` ?
# - A) -20
# - B) 20
# - C) 0
#
# **Question 2 :** Quel est le résultat de `round(5.4)` ?
# - A) 5
# - B) 5.4
# - C) 6
#
# **Question 3 :** Comment arrondir 2.71828 à 3 décimales ?
# - A) `round(2.71828, 3)`
# - B) `round(2.71828)`
# - C) `abs(2.71828, 3)`
#
# <details>
# <summary>✅ Correction</summary>
#
# **Question 1 :** B) 20
# **Explication :** La valeur absolue d'un nombre négatif est sa valeur positive.
#
# **Question 2 :** A) 5
# **Explication :** 5.4 est plus proche de 5 que de 6.
#
# **Question 3 :** A) `round(2.71828, 3)`
# **Explication :** Le deuxième paramètre indique le nombre de décimales.
# </details>

# %% [markdown]
# ### 🔍 Exercice 9 : Comprendre un programme
#
# **Que fait le programme suivant et quel est son résultat ?**

# %%
abs(8 - 15)

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# Ce programme calcule d'abord `8 - 15 = -7`, puis la valeur absolue de -7.
# Résultat : **7**
#
# La fonction `abs()` permet de calculer la distance entre deux nombres.
# </details>

# %% [markdown]
# ### 💡 Exercice 10 : Application
#
# **A) Utilisez les fonctions pour calculer :**
#
# 1. La valeur absolue de -42
# 2. L'arrondi de 6.89 à l'entier le plus proche
# 3. L'arrondi de 6.89 à 1 décimale
# 4. $3^5$ avec `pow()`

# %%
# Écrivez votre code ici

# %% [markdown]
# **B) Écrivez un programme qui calcule la distance entre 12 et 27**
#
# *Indice : La distance entre deux nombres est la valeur absolue de leur différence.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction A</summary>
#
# ```python
# abs(-42)         # 42
# round(6.89)      # 7
# round(6.89, 1)   # 6.9
# pow(3, 5)        # 243
# ```
# </details>
#
# <details>
# <summary>💡 Correction B</summary>
#
# ```python
# abs(12 - 27)  # 15
# # ou abs(27 - 12) donne le même résultat
# ```
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Exercices de synthèse
#
# ### Exercice 11 : Calcul d'une expression complexe
#
# Calculez la valeur de l'expression suivante :
#
# $$\dfrac{7^2 + 3 \times 5}{\left|4 - 12\right| + 2}$$
#
# *Rappel : Utilisez `abs()` pour la valeur absolue et des parenthèses pour les fractions.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# (7**2 + 3 * 5) / (abs(4 - 12) + 2)  # 6.4
# ```
#
# **Détail du calcul :**
# - Numérateur : $7^2 + 3 \times 5 = 49 + 15 = 64$
# - Dénominateur : $|4 - 12| + 2 = |-8| + 2 = 8 + 2 = 10$
# - Résultat : $\dfrac{64}{10} = 6.4$
# </details>

# %% [markdown]
# ### Exercice 12 : Problème de divisibilité
#
# Un nombre est divisible par 9 si le reste de sa division euclidienne par 9 est égal à 0.
#
# Parmi les nombres 81, 100, 117 et 200, lesquels sont divisibles par 9 ?
#
# Affichez les restes pour chacun avec `print()`.

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# print("81 % 9 =", 81 % 9)     # 0 → divisible
# print("100 % 9 =", 100 % 9)   # 1 → non divisible
# print("117 % 9 =", 117 % 9)   # 0 → divisible
# print("200 % 9 =", 200 % 9)   # 2 → non divisible
# ```
#
# **Réponse :** 81 et 117 sont divisibles par 9.
# </details>

# %% [markdown]
# ### Exercice 13 : Moyenne arrondie
#
# Calculez la moyenne des nombres 14, 17, 19 et 22, puis affichez le résultat arrondi à 1 décimale.
#
# *Rappel : La moyenne de 4 nombres se calcule en les additionnant puis en divisant par 4.*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# moyenne = (14 + 17 + 19 + 22) / 4
# print("Moyenne arrondie :", round(moyenne, 1))  # 18.0
# ```
# </details>

# %% [markdown]
# ---
#
# ## 🏆 Challenge final : Problème du billet de banque
#
# Vous avez **157 euros** et vous souhaitez les échanger contre des billets de **10 euros** uniquement.
#
# 1. Combien de billets de 10 euros pouvez-vous obtenir ?
# 2. Combien d'euros vous restera-t-il ?
# 3. Affichez les résultats avec des phrases complètes.
#
# *Indice : C'est une division euclidienne !*

# %%
# Écrivez votre code ici

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# argent = 157
# billet = 10
#
# nb_billets = argent // billet
# reste = argent % billet
#
# print("Nombre de billets de 10€ :", nb_billets)
# print("Il vous restera :", reste, "€")
# ```
#
# **Résultat :**
# ```
# Nombre de billets de 10€ : 15
# Il vous restera : 7 €
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📝 Synthèse
#
# Dans cette activité, vous avez appris à :
# - ✅ Utiliser les opérateurs arithmétiques : `+`, `-`, `*`, `/`, `**`
# - ✅ Respecter les priorités opératoires et utiliser des parenthèses
# - ✅ Effectuer des divisions euclidiennes avec `//` et `%`
# - ✅ Afficher des résultats avec `print()`
# - ✅ Utiliser des fonctions mathématiques : `abs()`, `round()`, `pow()`
#
# **Félicitations ! Vous savez maintenant utiliser Python comme une calculatrice évoluée ! 🎉**
