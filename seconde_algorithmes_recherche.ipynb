# %% [markdown]
# # 🔍 Algorithmes de recherche : maximum et minimum
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Seconde<br>
#     <strong>🎯 Thème mathématique :</strong> Algorithmique et programmation<br>
#     <strong>⏱️ Durée estimée :</strong> 45-60 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# À la fin de cette activité, vous serez capable de :
# - ✅ Parcourir une liste avec une boucle for
# - ✅ Rechercher le maximum d'une série de valeurs
# - ✅ Rechercher le minimum d'une série de valeurs
# - ✅ Mettre à jour une variable selon une condition

# %% [markdown]
# ---
#
# ## 📋 Prérequis
#
# <div style="background-color: #fff3cd; padding: 10px; border-radius: 5px;">
# Pour cette activité, vous devez savoir :
#
# - 📌 Utiliser une boucle `for` pour répéter des instructions
# - 📌 Utiliser une condition `if` pour tester une propriété
# - 📌 Manipuler des listes en Python
# </div>

# %% [markdown]
# ---
#
# ## 💡 Introduction
#
# En mathématiques et en sciences, on a souvent besoin de trouver la **plus grande** ou la **plus petite** valeur dans un ensemble de données :
# - Température maximale d'une semaine
# - Note minimale d'un contrôle
# - Prix le plus bas dans une liste
# - Maximum d'une fonction sur un intervalle
#
# <div style="background-color: #f0f4c3; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>🤔 Problème :</strong> Comment trouver automatiquement le maximum ou le minimum parmi des dizaines, voire des centaines de valeurs ?<br>
#     <strong>✨ Solution :</strong> Utiliser un <strong>algorithme de recherche</strong> qui parcourt les données et retient la meilleure valeur !
# </div>

# %% [markdown]
# ---
#
# ## 1️⃣ Parcourir une liste
#
# <div style="background-color: #e8f5e9; padding: 15px; border-radius: 10px; border-left: 5px solid #4CAF50;">
#     <strong>📖 Rappel :</strong> Une liste est une collection ordonnée de valeurs. On peut parcourir tous ses éléments avec une boucle <code>for</code>.
# </div>
#
# ### 🔧 Deux méthodes de parcours
#
# **Méthode 1 : Parcourir les valeurs directement**
# ```python
# for valeur in liste:
#     print(valeur)
# ```
#
# **Méthode 2 : Parcourir par indices**
# ```python
# for i in range(len(liste)):
#     print(liste[i])
# ```
#
# ### 📝 Exemple complet résolu

# %%
# ✅ EXEMPLE RÉSOLU : Afficher toutes les températures d'une semaine
temperatures = [18, 22, 19, 25, 23, 20, 21]

print("🌡️ Températures de la semaine :")
jours = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

for i in range(len(temperatures)):
    print(f"{jours[i]} : {temperatures[i]}°C")

# %% [markdown]
# <div style="background-color: #e1f5fe; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>💬 Explication :</strong>
#     <ul>
#         <li><code>len(temperatures)</code> renvoie la longueur de la liste (7)</li>
#         <li><code>range(7)</code> génère 0, 1, 2, 3, 4, 5, 6</li>
#         <li><code>temperatures[i]</code> accède à l'élément à l'indice i</li>
#     </ul>
# </div>
#
# ### 🧪 Exemple 2 : À vous de compléter !

# %%
# 🔨 À COMPLÉTER : Afficher toutes les notes d'un élève
# Indice : parcourez directement les valeurs avec "for note in notes"

notes = [12, 15, 8, 17, 14, 11]

print("📝 Notes de l'élève :")
for ____ in ____:  # Complétez
    print(f"Note : {____}/20")  # Complétez

# %% [markdown]
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
# <summary>💡 Cliquez pour voir la solution</summary>
#
# ```python
# for note in notes:
#     print(f"Note : {note}/20")
# ```
# </details>

# %% [markdown]
# ---
#
# ## 2️⃣ Rechercher le maximum
#
# <div style="background-color: #fff9c4; padding: 15px; border-radius: 10px; border-left: 5px solid #FFC107;">
#     <strong>🎯 Objectif :</strong> Trouver la plus grande valeur dans une liste.
# </div>
#
# ### 🧠 Principe de l'algorithme
#
# 1. On initialise une variable `maximum` avec la première valeur de la liste
# 2. On parcourt toutes les autres valeurs
# 3. Si on trouve une valeur **plus grande**, on met à jour `maximum`
# 4. À la fin, `maximum` contient la plus grande valeur
#
# ### 📝 Exemple complet résolu

# %%
# ✅ EXEMPLE RÉSOLU : Trouver la température maximale
temperatures = [18, 22, 19, 25, 23, 20, 21]

# Initialisation : on suppose que le premier élément est le maximum
maximum = temperatures[0]

# Parcours de la liste
for temp in temperatures:
    if temp > maximum:
        maximum = temp  # Mise à jour du maximum
        print(f"  Nouveau maximum trouvé : {maximum}°C")

print(f"\n🔥 Température maximale de la semaine : {maximum}°C")

# %% [markdown]
# <div style="background-color: #e1f5fe; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>💬 Explication :</strong>
#     <ul>
#         <li><code>maximum = temperatures[0]</code> : on initialise avec le premier élément</li>
#         <li><code>if temp > maximum</code> : on teste si la valeur actuelle est plus grande</li>
#         <li><code>maximum = temp</code> : si oui, on remplace maximum par cette nouvelle valeur</li>
#     </ul>
# </div>
#
# ### 🧪 Exemple 2 : À vous de compléter !

# %%
# 🔨 À COMPLÉTER : Trouver la note maximale
# Indice : initialisez avec notes[0], puis testez if note > maximum

notes = [12, 15, 8, 17, 14, 11]

maximum = ____  # Initialisation

for note in notes:
    if ____:  # Condition de comparaison
        maximum = ____  # Mise à jour

print(f"📊 Note maximale : {maximum}/20")

# %% [markdown]
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
# <summary>💡 Cliquez pour voir la solution</summary>
#
# ```python
# maximum = notes[0]
#
# for note in notes:
#     if note > maximum:
#         maximum = note
#
# print(f"📊 Note maximale : {maximum}/20")
# ```
# </details>
#
# ### 🧪 Exemple 3 : À vous de compléter !

# %%
# 🔨 À COMPLÉTER : Trouver la plus grande valeur d'une fonction
# On a calculé f(x) = -x² + 6x pour x de 0 à 6

valeurs_f = [0, 5, 8, 9, 8, 5, 0]  # f(0), f(1), f(2), f(3), f(4), f(5), f(6)

maximum = valeurs_f[0]

for valeur in ____:  # Parcourir la liste
    if ____:  # Comparer
        ____  # Mettre à jour

print(f"📈 Maximum de la fonction : {maximum}")

# %% [markdown]
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
# <summary>💡 Cliquez pour voir la solution</summary>
#
# ```python
# maximum = valeurs_f[0]
#
# for valeur in valeurs_f:
#     if valeur > maximum:
#         maximum = valeur
#
# print(f"📈 Maximum de la fonction : {maximum}")
# ```
# </details>

# %% [markdown]
# ---
#
# ## 3️⃣ Rechercher le minimum
#
# <div style="background-color: #e8f5e9; padding: 15px; border-radius: 10px; border-left: 5px solid #4CAF50;">
#     <strong>📖 Principe :</strong> L'algorithme de recherche du minimum est identique à celui du maximum, mais on teste <code>if valeur < minimum</code> au lieu de <code>></code>.
# </div>
#
# ### 📝 Exemple complet résolu

# %%
# ✅ EXEMPLE RÉSOLU : Trouver le prix le plus bas
prix = [45.99, 32.50, 28.90, 51.20, 39.00]

minimum = prix[0]

for p in prix:
    if p < minimum:
        minimum = p
        print(f"  Nouveau minimum trouvé : {minimum}€")

print(f"\n💰 Prix le plus bas : {minimum}€")

# %% [markdown]
# <div style="background-color: #e1f5fe; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>💬 Explication :</strong>
#     <ul>
#         <li>Le principe est le même que pour le maximum</li>
#         <li>On change juste <code>></code> en <code><</code></li>
#         <li>On initialise toujours avec le premier élément</li>
#     </ul>
# </div>
#
# ### 🧪 Exemple 2 : À vous de compléter !

# %%
# 🔨 À COMPLÉTER : Trouver la note minimale

notes = [12, 15, 8, 17, 14, 11]

minimum = ____  # Initialisation

for note in notes:
    if ____:  # Condition
        minimum = ____  # Mise à jour

print(f"📉 Note minimale : {minimum}/20")

# %% [markdown]
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
# <summary>💡 Cliquez pour voir la solution</summary>
#
# ```python
# minimum = notes[0]
#
# for note in notes:
#     if note < minimum:
#         minimum = note
#
# print(f"📉 Note minimale : {minimum}/20")
# ```
# </details>

# %% [markdown]
# ---
#
# ## 4️⃣ Trouver l'indice du maximum ou du minimum
#
# <div style="background-color: #e8f5e9; padding: 15px; border-radius: 10px; border-left: 5px solid #4CAF50;">
#     <strong>📖 Objectif :</strong> En plus de la valeur maximale, on veut aussi savoir <strong>où elle se trouve</strong> dans la liste (son indice).
# </div>
#
# ### 🔧 Méthode
#
# On utilise deux variables :
# - `maximum` : pour stocker la plus grande valeur
# - `indice_max` : pour stocker sa position
#
# ### 📝 Exemple complet résolu

# %%
# ✅ EXEMPLE RÉSOLU : Trouver quel jour il a fait le plus chaud
temperatures = [18, 22, 19, 25, 23, 20, 21]
jours = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

maximum = temperatures[0]
indice_max = 0

for i in range(len(temperatures)):
    if temperatures[i] > maximum:
        maximum = temperatures[i]
        indice_max = i

print(f"🔥 Jour le plus chaud : {jours[indice_max]} avec {maximum}°C")

# %% [markdown]
# <div style="background-color: #e1f5fe; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>💬 Explication :</strong>
#     <ul>
#         <li>On parcourt avec <code>range(len(...))</code> pour avoir les indices</li>
#         <li>On met à jour <code>maximum</code> ET <code>indice_max</code> simultanément</li>
#         <li><code>indice_max</code> garde la position de la valeur maximale</li>
#     </ul>
# </div>
#
# ### 🧪 Exemple 2 : À vous de compléter !

# %%
# 🔨 À COMPLÉTER : Trouver pour quelle valeur de x la fonction atteint son maximum
# On a calculé f(x) = -x² + 6x pour x de 0 à 6

x_valeurs = [0, 1, 2, 3, 4, 5, 6]
f_valeurs = [0, 5, 8, 9, 8, 5, 0]

maximum = f_valeurs[0]
indice_max = 0

for i in range(len(f_valeurs)):
    if ____:  # Condition
        maximum = ____  # Mettre à jour le maximum
        indice_max = ____  # Mettre à jour l'indice

print(f"📈 Maximum de f : {maximum} atteint en x = {x_valeurs[indice_max]}")

# %% [markdown]
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
# <summary>💡 Cliquez pour voir la solution</summary>
#
# ```python
# for i in range(len(f_valeurs)):
#     if f_valeurs[i] > maximum:
#         maximum = f_valeurs[i]
#         indice_max = i
#
# print(f"📈 Maximum de f : {maximum} atteint en x = {x_valeurs[indice_max]}")
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📝 À votre tour ! Exercices
#
# <div style="background-color: #ffebee; padding: 15px; border-radius: 10px; border-left: 5px solid #f44336;">
#     <strong>⚠️ Important :</strong> Ces exercices sont entièrement à faire par vous-même. Essayez d'abord sans regarder les solutions !
# </div>
#
# ### 📌 Exercice 1 : Maximum et minimum
#
# Pour la liste `distances = [125, 89, 203, 67, 145, 98]` (en km) :
# 1. Trouvez la distance maximale
# 2. Trouvez la distance minimale
# 3. Calculez l'écart entre les deux (max - min)

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ### 📌 Exercice 2 : Images d'une fonction
#
# On a calculé les images de la fonction $f(x) = x^2 - 5x + 4$ pour $x$ de 0 à 5 :
# ```python
# images = [4, 0, -2, -2, 0, 4]
# ```
# Trouvez le minimum de ces images.

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ### 📌 Exercice 3 : Jour le plus froid
#
# Voici les températures d'une semaine d'hiver :
# ```python
# temperatures = [3, -1, 2, 5, -2, 0, 4]
# jours = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]
# ```
# Trouvez quel jour il a fait le plus froid (minimum) et affichez ce jour avec sa température.

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ### 📌 Exercice 4 : Amplitude
#
# L'amplitude d'une série de valeurs est la différence entre le maximum et le minimum.
#
# Calculez l'amplitude de ces relevés de hauteur d'eau (en cm) :
# ```python
# hauteurs = [152, 148, 155, 147, 151, 149, 153]
# ```

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ### 📌 Exercice 5 : Meilleure moyenne
#
# Trois élèves ont les moyennes suivantes dans différentes matières :
# ```python
# alice = [12, 15, 14, 16]
# bob = [13, 11, 15, 14]
# claire = [16, 14, 13, 15]
# ```
#
# Pour chaque élève, calculez sa note maximale. Puis déterminez qui a la meilleure note maximale.

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ---
#
# ## 🎁 Pour aller plus loin (Challenge)
#
# ### 🏆 Exercice 6 : Maximum d'une fonction calculée
#
# Pour la fonction $f(x) = -x^2 + 4x + 5$ :
# 1. Calculez ses images pour $x$ variant de -2 à 6 (avec `range(-2, 7)`)
# 2. Trouvez la valeur maximale de $f(x)$
# 3. Trouvez pour quelle valeur de $x$ ce maximum est atteint
# 4. Affichez : "Le maximum de f est ... atteint en x = ..."

# %%
# 💻 Écrivez votre code ici

# %% [markdown]
# ---
#
# ## ✅ Corrections
#
# <div style="background-color: #f1f8e9; padding: 10px; border-radius: 5px; margin: 10px 0;">
#     <strong>💡 Astuce :</strong> Essayez d'abord par vous-même avant de regarder les corrections !
# </div>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>📌 Correction exercice 1</strong></summary>
#
# ```python
# distances = [125, 89, 203, 67, 145, 98]
#
# # Maximum
# maximum = distances[0]
# for d in distances:
#     if d > maximum:
#         maximum = d
#
# # Minimum
# minimum = distances[0]
# for d in distances:
#     if d < minimum:
#         minimum = d
#
# # Écart
# ecart = maximum - minimum
#
# print(f"Distance maximale : {maximum} km")
# print(f"Distance minimale : {minimum} km")
# print(f"Écart : {ecart} km")  # 203 - 67 = 136 km
# ```
# </details>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>📌 Correction exercice 2</strong></summary>
#
# ```python
# images = [4, 0, -2, -2, 0, 4]
#
# minimum = images[0]
# for img in images:
#     if img < minimum:
#         minimum = img
#
# print(f"Minimum de f : {minimum}")  # -2
# ```
# </details>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>📌 Correction exercice 3</strong></summary>
#
# ```python
# temperatures = [3, -1, 2, 5, -2, 0, 4]
# jours = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]
#
# minimum = temperatures[0]
# indice_min = 0
#
# for i in range(len(temperatures)):
#     if temperatures[i] < minimum:
#         minimum = temperatures[i]
#         indice_min = i
#
# print(f"Jour le plus froid : {jours[indice_min]} avec {minimum}°C")  # Vendredi avec -2°C
# ```
# </details>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>📌 Correction exercice 4</strong></summary>
#
# ```python
# hauteurs = [152, 148, 155, 147, 151, 149, 153]
#
# maximum = hauteurs[0]
# minimum = hauteurs[0]
#
# for h in hauteurs:
#     if h > maximum:
#         maximum = h
#     if h < minimum:
#         minimum = h
#
# amplitude = maximum - minimum
# print(f"Amplitude : {amplitude} cm")  # 155 - 147 = 8 cm
# ```
# </details>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>📌 Correction exercice 5</strong></summary>
#
# ```python
# alice = [12, 15, 14, 16]
# bob = [13, 11, 15, 14]
# claire = [16, 14, 13, 15]
#
# # Maximum d'Alice
# max_alice = alice[0]
# for note in alice:
#     if note > max_alice:
#         max_alice = note
#
# # Maximum de Bob
# max_bob = bob[0]
# for note in bob:
#     if note > max_bob:
#         max_bob = note
#
# # Maximum de Claire
# max_claire = claire[0]
# for note in claire:
#     if note > max_claire:
#         max_claire = note
#
# print(f"Maximum d'Alice : {max_alice}")
# print(f"Maximum de Bob : {max_bob}")
# print(f"Maximum de Claire : {max_claire}")
#
# # Meilleure note maximale
# if max_alice > max_bob and max_alice > max_claire:
#     print("Alice a la meilleure note maximale")
# elif max_bob > max_claire:
#     print("Bob a la meilleure note maximale")
# else:
#     print("Claire a la meilleure note maximale")  # 16
# ```
# </details>
#
# <details style="background-color: #f5f5f5; padding: 10px; border-radius: 5px; margin: 10px 0;">
# <summary><strong>🏆 Correction exercice 6 (Challenge)</strong></summary>
#
# ```python
# def f(x):
#     return -x**2 + 4*x + 5
#
# # Calculer toutes les images
# x_valeurs = []
# f_valeurs = []
#
# for x in range(-2, 7):
#     x_valeurs.append(x)
#     f_valeurs.append(f(x))
#
# # Chercher le maximum
# maximum = f_valeurs[0]
# indice_max = 0
#
# for i in range(len(f_valeurs)):
#     if f_valeurs[i] > maximum:
#         maximum = f_valeurs[i]
#         indice_max = i
#
# print(f"Le maximum de f est {maximum} atteint en x = {x_valeurs[indice_max]}")
# # Maximum = 9 en x = 2
# ```
# </details>

# %% [markdown]
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Parcourir une liste avec une boucle `for`
# - ✅ Implémenter un algorithme de recherche du maximum
# - ✅ Implémenter un algorithme de recherche du minimum
# - ✅ Trouver l'indice (position) du maximum ou du minimum
#
# ### 🔑 Points clés à retenir
#
# | Algorithme | Initialisation | Condition | Mise à jour |
# |------------|----------------|-----------|-------------|
# | Maximum | `max = liste[0]` | `if val > max` | `max = val` |
# | Minimum | `min = liste[0]` | `if val < min` | `min = val` |
#
# ⚠️ **Important :** Toujours initialiser avec le **premier élément** de la liste, pas avec 0 !
#
# ### 🎯 Applications mathématiques
#
# - 📊 Statistiques : trouver des extremums dans des données
# - 📈 Fonctions : déterminer le maximum ou minimum d'une fonction
# - 🔢 Suites numériques : analyser le comportement
# - 📉 Optimisation : chercher la meilleure solution
#
# </div>
#
# ---
#
# <div style="background-color: #c8e6c9; padding: 15px; border-radius: 10px; text-align: center;">
#     <strong>🎉 Bravo ! Vous avez terminé cette activité !</strong><br>
#     Vous maîtrisez maintenant les algorithmes de recherche essentiels ! Continuez avec les notebooks de Première 🚀
# </div>
