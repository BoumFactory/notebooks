# %% [markdown]
# # 📐 Méthode d'Archimède : Approximation de π
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Première / Terminale<br>
#     <strong>🎯 Thème mathématique :</strong> Géométrie - Suites<br>
#     <strong>⏱️ Durée estimée :</strong> 45-60 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# - ✅ Comprendre la méthode historique d'Archimède
# - ✅ Approximer π par des polygones
# - ✅ Calculer des périmètres de polygones réguliers
# - ✅ Observer la convergence vers π
#
# ---
#
# ## 💡 Principe
#
# Archimède a encadré π en calculant les périmètres de polygones réguliers inscrits et circonscrits dans un cercle de rayon 1.
#
# Plus le polygone a de côtés, plus son périmètre se rapproche de $2\pi$.
#
# Pour un polygone régulier à $n$ côtés inscrit dans un cercle de rayon 1 :
#
# $$P_n = 2n \sin\left(\dfrac{\pi}{n}\right)$$
#
# Donc : $\pi \approx \dfrac{P_n}{2}$
#
# ---

# %% [markdown]
# ## 📚 Partie 1 : Périmètre d'un polygone
#
# ### ✍️ Exercice 1 : Fonction périmètre
#
# Écrivez une fonction `perimetre_polygone(n)` qui calcule le périmètre d'un polygone régulier à $n$ côtés inscrit dans un cercle de rayon 1.

# %%
import math

def perimetre_polygone(n):
    # P_n = 2n sin(π/n)
    pass

# Tests
print("Périmètres :")
print(f"Triangle (n=3) : {perimetre_polygone(3):.6f}")
print(f"Carré (n=4) : {perimetre_polygone(4):.6f}")
print(f"Hexagone (n=6) : {perimetre_polygone(6):.6f}")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def perimetre_polygone(n):
#     return 2 * n * math.sin(math.pi / n)
# ```
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 2 : Approximation de π
#
# ### ✍️ Exercice 2 : Estimation
#
# Écrivez une fonction `approx_pi(n)` qui estime π à partir d'un polygone à $n$ côtés.

# %%
def approx_pi(n):
    # π ≈ P_n / 2
    pass

# Tests avec différentes valeurs
print(f"π réel = {math.pi:.10f}\n")

for n in [3, 6, 12, 24, 48, 96, 192]:
    pi_approx = approx_pi(n)
    erreur = abs(pi_approx - math.pi)
    print(f"n = {n:3d} → π ≈ {pi_approx:.10f} (erreur : {erreur:.2e})")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def approx_pi(n):
#     return perimetre_polygone(n) / 2
# ```
#
# **Observation :** Archimède est allé jusqu'à $n = 96$ pour obtenir $\pi \approx 3{,}14$.
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 3 : Visualisation
#
# ### ✍️ Exercice 3 : Convergence graphique
#
# Tracez l'évolution de l'erreur en fonction de $n$.

# %%
import matplotlib.pyplot as plt

plt.clf()

n_values = [3, 6, 12, 24, 48, 96, 192, 384, 768]
erreurs = [abs(approx_pi(n) - math.pi) for n in n_values]

plt.plot(n_values, erreurs, 'bo-')
plt.xlabel('Nombre de côtés n')
plt.ylabel('Erreur |π_approx - π|')
plt.title('Convergence de la méthode d\'Archimède')
plt.yscale('log')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ---
#
# ## 🏆 Challenge final : Polygones circonscrits
#
# Pour un polygone **circonscrit** à un cercle de rayon 1, le périmètre est :
#
# $$Q_n = 2n \tan\left(\dfrac{\pi}{n}\right)$$
#
# Archimède utilisait les deux pour encadrer π :
#
# $$\dfrac{P_n}{2} < \pi < \dfrac{Q_n}{2}$$
#
# Calculez cet encadrement pour $n = 96$ (comme Archimède).

# %%
def perimetre_circonscrit(n):
    # Complétez ici
    pass

n = 96
borne_inf = approx_pi(n)
borne_sup = perimetre_circonscrit(n) / 2

print(f"Encadrement d'Archimède avec n = {n} :")
print(f"{borne_inf:.6f} < π < {borne_sup:.6f}")
print(f"\nValeur réelle : π = {math.pi:.6f}")
print(f"Largeur de l'encadrement : {borne_sup - borne_inf:.6f}")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def perimetre_circonscrit(n):
#     return 2 * n * math.tan(math.pi / n)
# ```
#
# **Résultat d'Archimède :** $3{,}1408 < \pi < 3{,}1429$
# </details>
#
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Méthode historique d'approximation de π
# - ✅ Calcul de périmètres de polygones réguliers
# - ✅ Encadrement par inscrit/circonscrit
# - ✅ Convergence d'une suite
#
# ### 🔑 Formules clés
#
# | Polygone | Périmètre | Approximation de π |
# |---|---|---|
# | Inscrit | $P_n = 2n \sin(\pi/n)$ | $\pi \approx P_n/2$ |
# | Circonscrit | $Q_n = 2n \tan(\pi/n)$ | $\pi \approx Q_n/2$ |
#
# **Archimède (250 av. J.-C.)** : $3{,}1408 < \pi < 3{,}1429$ avec $n = 96$
#
# </div>
