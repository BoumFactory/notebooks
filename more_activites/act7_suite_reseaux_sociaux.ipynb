# %% [markdown]
# # 📱 Croissance d'un réseau social : Suites numériques
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Première<br>
#     <strong>🎯 Thème mathématique :</strong> Suites numériques<br>
#     <strong>⏱️ Durée estimée :</strong> 45-60 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# - ✅ Modéliser une situation par une suite
# - ✅ Calculer les termes d'une suite de manière itérative
# - ✅ Visualiser l'évolution d'une suite
# - ✅ Comparer suites arithmétiques et géométriques
#
# ---
#
# ## 📋 Situation
#
# Un nouveau réseau social compte initialement $u_0 = 1000$ membres.
#
# **Modèle 1 :** Chaque mois, 50 nouveaux membres s'inscrivent (suite arithmétique).
#
# **Modèle 2 :** Chaque mois, le nombre de membres augmente de 5% (suite géométrique).
#
# ---

# %% [markdown]
# ## 📚 Partie 1 : Suite arithmétique
#
# ### ✍️ Exercice 1 : Calcul itératif
#
# Modèle 1 : $u_{n+1} = u_n + 50$ avec $u_0 = 1000$.
#
# Écrivez une fonction `suite_arithmetique(u0, r, n)` qui renvoie le terme $u_n$ d'une suite arithmétique.

# %%
def suite_arithmetique(u0, r, n):
    # Méthode itérative
    # u = u0
    # Pour i de 0 à n-1 :
    #   u = u + r
    # Retourner u
    pass

# Test
u0 = 1000
r = 50
print("Évolution du nombre de membres (Modèle 1) :")
for mois in [0, 6, 12, 24]:
    print(f"Mois {mois:2d} : {suite_arithmetique(u0, r, mois)} membres")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def suite_arithmetique(u0, r, n):
#     u = u0
#     for i in range(n):
#         u = u + r
#     return u
# ```
#
# Ou directement avec la formule : `return u0 + n * r`
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 2 : Suite géométrique
#
# ### ✍️ Exercice 2 : Croissance exponentielle
#
# Modèle 2 : $u_{n+1} = 1{,}05 \times u_n$ avec $u_0 = 1000$.
#
# Écrivez une fonction `suite_geometrique(u0, q, n)` qui renvoie $u_n$.

# %%
def suite_geometrique(u0, q, n):
    # Complétez ici
    pass

# Test
u0 = 1000
q = 1.05
print("Évolution du nombre de membres (Modèle 2) :")
for mois in [0, 6, 12, 24]:
    print(f"Mois {mois:2d} : {suite_geometrique(u0, q, mois):.0f} membres")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def suite_geometrique(u0, q, n):
#     u = u0
#     for i in range(n):
#         u = u * q
#     return u
# ```
#
# Ou directement : `return u0 * q**n`
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 3 : Comparaison graphique
#
# ### ✍️ Exercice 3 : Tracé des deux modèles
#
# Tracez les deux courbes sur 36 mois pour comparer.

# %%
import matplotlib.pyplot as plt

plt.clf()

# Complétez ici :
# Créer deux listes (une pour chaque modèle)
# Pour n de 0 à 36 : calculer les termes
# Tracer les deux courbes

plt.xlabel('Mois')
plt.ylabel('Nombre de membres')
plt.title('Croissance du réseau social : Deux modèles')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# plt.clf()
#
# mois = range(37)
# modele1 = [suite_arithmetique(1000, 50, n) for n in mois]
# modele2 = [suite_geometrique(1000, 1.05, n) for n in mois]
#
# plt.plot(mois, modele1, 'b-', label='Modèle 1 (arithmétique +50/mois)')
# plt.plot(mois, modele2, 'r-', label='Modèle 2 (géométrique ×1.05)')
#
# plt.xlabel('Mois')
# plt.ylabel('Nombre de membres')
# plt.title('Croissance du réseau social : Deux modèles')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.show()
# ```
#
# **Observation :** La croissance géométrique finit par dépasser largement la croissance arithmétique.
# </details>
#
# ---
#
# ## 🏆 Challenge final : Seuil
#
# À partir de quel mois le réseau dépasse-t-il 5000 membres dans chaque modèle ?

# %%
def premier_mois_au_dessus(u0, evolution, seuil):
    """
    evolution : fonction qui prend (u0, param, n) et renvoie u_n
    """
    # Complétez ici
    pass

# Tests
seuil = 5000
print(f"Seuil de {seuil} membres atteint :")
# Modèle 1
# Modèle 2

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# # Modèle 1
# n = 0
# while suite_arithmetique(1000, 50, n) < 5000:
#     n += 1
# print(f"Modèle 1 : mois {n} ({suite_arithmetique(1000, 50, n)} membres)")
#
# # Modèle 2
# n = 0
# while suite_geometrique(1000, 1.05, n) < 5000:
#     n += 1
# print(f"Modèle 2 : mois {n} ({suite_geometrique(1000, 1.05, n):.0f} membres)")
# ```
#
# **Résultats attendus :** Modèle 1 ≈ 80 mois, Modèle 2 ≈ 33 mois
# </details>
#
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Modélisation par suites arithmétiques et géométriques
# - ✅ Calcul itératif de termes
# - ✅ Comparaison de croissances
# - ✅ Recherche de seuil
#
# ### 🔑 Formules clés
#
# | Type | Récurrence | Terme général |
# |---|---|---|
# | Arithmétique | $u_{n+1} = u_n + r$ | $u_n = u_0 + nr$ |
# | Géométrique | $u_{n+1} = q \times u_n$ | $u_n = u_0 \times q^n$ |
#
# </div>
