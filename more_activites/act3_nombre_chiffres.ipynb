# %% [markdown]
# # 🔢 Nombre de chiffres d'un entier
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Seconde<br>
#     <strong>🎯 Thème mathématique :</strong> Puissances<br>
#     <strong>⏱️ Durée estimée :</strong> 30-45 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# - ✅ Déterminer programmatiquement le nombre de chiffres d'un entier
# - ✅ Comprendre le lien entre puissances de 10 et nombre de chiffres
# - ✅ Visualiser graphiquement l'évolution du nombre de chiffres des puissances de 2
#
# ---
#
# ## 💡 Introduction
#
# Comment déterminer rapidement le nombre de chiffres d'un très grand nombre comme $2^{100}$ ?
#
# **Observation mathématique :**
# - $10^0 = 1$ a 1 chiffre
# - $10^1 = 10$ a 2 chiffres
# - $10^2 = 100$ a 3 chiffres
# - $10^n$ a $n+1$ chiffres
#
# **Donc :** Si $10^n \leq a < 10^{n+1}$, alors $a$ a $n+1$ chiffres.
#
# ---

# %% [markdown]
# ## 📚 Partie 1 : Fonction de comptage
#
# ### ✍️ Exercice 1 : Nombre de chiffres
#
# Écrivez une fonction `nombre_chiffres(a)` qui prend un entier $a > 0$ et renvoie son nombre de chiffres.
#
# **Méthode :**
# 1. Initialiser $n = 0$
# 2. Tant que $10^n \leq a$ :
#    - Incrémenter $n$
# 3. Retourner $n$ (qui correspond au nombre de chiffres)

# %%
def nombre_chiffres(a):
    # Complétez ici
    pass

# Tests
print("109 a", nombre_chiffres(109), "chiffres")
print("1234 a", nombre_chiffres(1234), "chiffres")
print("5 a", nombre_chiffres(5), "chiffres")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def nombre_chiffres(a):
#     assert type(a) == int and a > 0, "a doit être un entier positif"
#     n = 0
#     while 10**n <= a:
#         n = n + 1
#     return n
# ```
#
# **Résultats attendus :**
# - 109 → 3 chiffres
# - 1234 → 4 chiffres
# - 5 → 1 chiffre
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 2 : Application aux puissances de 2
#
# ### ✍️ Exercice 2 : Puissances de 2
#
# Combien de chiffres ont $2^{10}$, $2^{64}$ et $2^{100}$ ?

# %%
# Complétez ici
print("2^10 a", nombre_chiffres(2**10), "chiffres")
print("2^10 =", 2**10)  # Vérification

print("\n2^64 a", nombre_chiffres(2**64), "chiffres")
print("2^100 a", nombre_chiffres(2**100), "chiffres")

# %% [markdown]
# ### 🤔 Question de réflexion
#
# On sait que $2^{10} = 1024 \approx 10^3$.
#
# En déduire une estimation du nombre de chiffres de $2^{100} = (2^{10})^{10}$.

# %% [markdown]
# <details>
# <summary>💡 Réponse</summary>
#
# $2^{100} = (2^{10})^{10} \approx (10^3)^{10} = 10^{30}$
#
# Donc $2^{100}$ a environ **31 chiffres** (car $10^{30}$ a 31 chiffres).
#
# Vérification avec Python : `nombre_chiffres(2**100)` donne bien 31.
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 3 : Visualisation graphique
#
# ### ✍️ Exercice 3 : Graphique d'évolution
#
# Tracez l'évolution du nombre de chiffres de $2^i$ pour $i$ allant de 0 à 100.

# %%
import matplotlib.pyplot as plt

plt.clf()

n = 100

# Complétez ici :
# Pour i de 0 à n :
#   Tracer le point (i, nombre_chiffres(2**i))

plt.xlabel('Exposant i')
plt.ylabel('Nombre de chiffres de 2^i')
plt.title('Évolution du nombre de chiffres des puissances de 2')
plt.grid(True)
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.clf()
#
# n = 100
#
# for i in range(n + 1):
#     plt.plot(i, nombre_chiffres(2**i), 'c.')
#
# plt.xlabel('Exposant i')
# plt.ylabel('Nombre de chiffres de 2^i')
# plt.title('Évolution du nombre de chiffres des puissances de 2')
# plt.grid(True)
# plt.show()
# ```
#
# **Observation :**
# - Forme en "escalier" : le nombre de chiffres n'augmente pas linéairement
# - Tendance générale : croissance logarithmique
# </details>
#
# ---

# %% [markdown]
# ## 🏆 Challenge final : Nombre de chiffres de factorielles
#
# Écrivez une fonction `factorielle(n)` qui calcule $n!$, puis déterminez combien de chiffres a $100!$.

# %%
def factorielle(n):
    # Complétez ici
    pass

# Tests
print("5! =", factorielle(5))
print("10! =", factorielle(10))

# Challenge
fact_100 = factorielle(100)
print(f"\n100! a {nombre_chiffres(fact_100)} chiffres")
print(f"Les 20 premiers chiffres : {str(fact_100)[:20]}...")

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def factorielle(n):
#     resultat = 1
#     for i in range(1, n + 1):
#         resultat = resultat * i
#     return resultat
# ```
#
# **Résultat :** $100!$ a **158 chiffres** !
# </details>
#
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Lien entre puissances de 10 et nombre de chiffres
# - ✅ Algorithme de comptage de chiffres
# - ✅ Visualisation de la croissance des puissances
#
# ### 🔑 Points clés
#
# | Nombre | Puissance de 10 | Nombre de chiffres |
# |---|---|---|
# | $10^n \leq a < 10^{n+1}$ | $n$ | $n+1$ |
#
# **Exemples :**
# - $2^{10} = 1024$ → 4 chiffres
# - $2^{64}$ → 20 chiffres
# - $2^{100}$ → 31 chiffres
# - $100!$ → 158 chiffres
#
# </div>
