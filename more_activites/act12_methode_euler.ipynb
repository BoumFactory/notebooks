# %% [markdown]
# # 🧮 Méthode d'Euler : Résolution d'équations différentielles
#
# <div style="background-color: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
#     <strong>📚 Niveau :</strong> Terminale<br>
#     <strong>🎯 Thème mathématique :</strong> Équations différentielles<br>
#     <strong>⏱️ Durée estimée :</strong> 60-75 min
# </div>
#
# ---
#
# ## 🎯 Objectifs
#
# - ✅ Comprendre le principe de la méthode d'Euler
# - ✅ Approximer la solution d'une équation différentielle
# - ✅ Visualiser la courbe solution
# - ✅ Comparer avec la solution exacte
#
# ---
#
# ## 💡 Principe
#
# Pour résoudre $y' = f(t, y)$ avec $y(t_0) = y_0$, on approche la courbe par une **ligne polygonale** :
#
# $$y_{n+1} = y_n + h \cdot f(t_n, y_n)$$
#
# où $h$ est le **pas** et $t_{n+1} = t_n + h$.
#
# **Idée :** On suit la tangente sur une petite distance.
#
# ---

# %% [markdown]
# ## 📚 Partie 1 : Équation $y' = y$
#
# ### 📖 Cas simple
#
# Résolvons $y' = y$ avec $y(0) = 1$.
#
# **Solution exacte :** $y(t) = e^t$
#
# ### ✍️ Exercice 1 : Implémentation
#
# Écrivez une fonction `euler(f, t0, y0, h, n)` qui applique la méthode d'Euler sur $n$ pas.

# %%
def euler(f, t0, y0, h, n):
    """
    Résout y' = f(t, y) par la méthode d'Euler.
    
    Paramètres:
    - f : fonction (t, y) → y'
    - t0, y0 : condition initiale
    - h : pas
    - n : nombre de pas
    
    Retourne : (liste_t, liste_y)
    """
    t = [t0]
    y = [y0]
    
    # Complétez ici :
    # Pour i de 0 à n-1 :
    #   t_suivant = t[-1] + h
    #   y_suivant = y[-1] + h * f(t[-1], y[-1])
    #   Ajouter à t et y
    
    return t, y

# Test avec y' = y
def f(t, y):
    return y

t, y = euler(f, 0, 1, 0.1, 10)
print("t =", [f"{ti:.1f}" for ti in t[:6]])
print("y =", [f"{yi:.4f}" for yi in y[:6]])

# %% [markdown]
# <details>
# <summary>💡 Correction</summary>
#
# ```python
# def euler(f, t0, y0, h, n):
#     t = [t0]
#     y = [y0]
#
#     for i in range(n):
#         t_suivant = t[-1] + h
#         y_suivant = y[-1] + h * f(t[-1], y[-1])
#         t.append(t_suivant)
#         y.append(y_suivant)
#
#     return t, y
# ```
# </details>
#
# ---

# %% [markdown]
# ## 📚 Partie 2 : Comparaison avec la solution exacte
#
# ### ✍️ Exercice 2 : Visualisation
#
# Tracez la solution d'Euler et la solution exacte $e^t$.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.clf()

# Méthode d'Euler
t_euler, y_euler = euler(f, 0, 1, 0.1, 50)

# Solution exacte
t_exact = np.linspace(0, 5, 200)
y_exact = np.exp(t_exact)

plt.plot(t_euler, y_euler, 'bo-', label='Euler (h=0.1)', markersize=4)
plt.plot(t_exact, y_exact, 'r-', label='Solution exacte $e^t$', linewidth=2)
plt.xlabel('t')
plt.ylabel('y')
plt.title("Méthode d'Euler pour y' = y")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### ✍️ Exercice 3 : Influence du pas
#
# Comparez les résultats pour $h = 0{,}5$, $h = 0{,}1$ et $h = 0{,}01$.

# %%
plt.clf()

# Complétez ici : tracer pour différents pas
for h, couleur in [(0.5, 'r'), (0.1, 'g'), (0.01, 'b')]:
    n = int(5 / h)
    t, y = euler(f, 0, 1, h, n)
    plt.plot(t, y, couleur + 'o-', label=f'h = {h}', markersize=3)

# Solution exacte
t_exact = np.linspace(0, 5, 200)
plt.plot(t_exact, np.exp(t_exact), 'k-', label='Exacte', linewidth=2)

plt.xlabel('t')
plt.ylabel('y')
plt.title("Influence du pas sur la méthode d'Euler")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **Observation :** Plus $h$ est petit, plus l'approximation est précise.
#
# ---

# %% [markdown]
# ## 📚 Partie 3 : Autres équations
#
# ### ✍️ Exercice 4 : Équation logistique
#
# Résolvez l'équation de croissance logistique : $y' = y(1 - y)$ avec $y(0) = 0{,}1$.
#
# Cette équation modélise une population qui tend vers 1.

# %%
plt.clf()

def g(t, y):
    return y * (1 - y)

t, y = euler(g, 0, 0.1, 0.1, 100)

plt.plot(t, y, 'b-')
plt.axhline(y=1, color='r', linestyle='--', label='Limite y=1')
plt.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
plt.xlabel('t')
plt.ylabel('y')
plt.title("Croissance logistique : y' = y(1-y)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"Limite observée : y({t[-1]:.1f}) = {y[-1]:.6f}")

# %% [markdown]
# ---
#
# ## 🏆 Challenge final : Oscillateur harmonique
#
# Résolvez le système d'équations différentielles :
#
# $$\begin{cases}
# x' = v \\
# v' = -x
# \end{cases}$$
#
# avec $x(0) = 1$ et $v(0) = 0$.
#
# **Indice :** Adaptez Euler pour un système à 2 variables.

# %%
def euler_2d(f1, f2, t0, x0, v0, h, n):
    """Euler pour système x'=f1(t,x,v), v'=f2(t,x,v)"""
    t = [t0]
    x = [x0]
    v = [v0]
    
    for i in range(n):
        t_new = t[-1] + h
        x_new = x[-1] + h * f1(t[-1], x[-1], v[-1])
        v_new = v[-1] + h * f2(t[-1], x[-1], v[-1])
        t.append(t_new)
        x.append(x_new)
        v.append(v_new)
    
    return t, x, v

# Système harmonique
def f1(t, x, v): return v
def f2(t, x, v): return -x

t, x, v = euler_2d(f1, f2, 0, 1, 0, 0.01, 1000)

# Tracé
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Position en fonction du temps
ax1.plot(t, x, 'b-')
ax1.set_xlabel('t')
ax1.set_ylabel('x(t)')
ax1.set_title('Position')
ax1.grid(True, alpha=0.3)

# Portrait de phase
ax2.plot(x, v, 'r-')
ax2.set_xlabel('x')
ax2.set_ylabel('v')
ax2.set_title('Portrait de phase')
ax2.grid(True, alpha=0.3)
ax2.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation :** Le portrait de phase devrait être un cercle (mouvement périodique).
#
# ---
#
# ## 📚 Synthèse
#
# <div style="background-color: #e8eaf6; padding: 20px; border-radius: 10px; border-left: 5px solid #3f51b5;">
#
# ### ✨ Ce que vous avez appris
#
# - ✅ Méthode d'Euler pour résoudre $y' = f(t, y)$
# - ✅ Influence du pas sur la précision
# - ✅ Applications : croissance exponentielle, logistique, oscillateur
# - ✅ Extension aux systèmes d'équations
#
# ### 🔑 Formule clé
#
# $$y_{n+1} = y_n + h \cdot f(t_n, y_n)$$
#
# **Avantages :** Simple, applicable à toute équation différentielle
#
# **Limites :** Erreur qui s'accumule, nécessite un pas petit
#
# </div>
